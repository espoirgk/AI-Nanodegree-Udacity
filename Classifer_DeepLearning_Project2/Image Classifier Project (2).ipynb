# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import json
from collections import OrderedDict
from PIL import Image

import torch
from torch import nn, optim
import torch.nn.functional as F

from torchvision import datasets, transforms, models
from torch.utils.data.sampler import SubsetRandomSampler

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=224),
        transforms.RandomRotation(45),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])
    ]),
    
    'valid': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])
    ])
}

# TODO: Load the datasets with ImageFolder
image_datasets = {
    'train': datasets.ImageFolder(train_dir, transform = data_transforms["train"]),
    'valid': datasets.ImageFolder(valid_dir, transform = data_transforms["valid"]),
    'test': datasets.ImageFolder(test_dir, transform = data_transforms["test"])
}

# TODO: Using the image datasets and the trainforms, define the dataloaders
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=64, shuffle=True)
              for x in ['train', 'valid', 'test']}
dataloaders
#Check for dataset sizes
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'valid', 'test']}
dataset_sizes
# Out:
# {'train': 6552, 'valid': 818, 'test': 819}

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %%
#Get a look on dataset
df_flower = pd.DataFrame.from_dict(cat_to_name, orient="index", columns=["type"])
df_flower.head()
# Out:
#                 type
# 21         fire lily
# 3   canterbury bells
# 45  bolero deep blue
# 1      pink primrose
# 34     mexican aster

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# <font color='red'>**Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.</font>

# %%
# TODO: Build and train your network
model = models.vgg16(pretrained=True)

#Here we freeze params of vg66 model
for param in model.parameters():
    param.requires_grad = False

#Create classifier by putting it in orderedDict
classifier = nn.Sequential(OrderedDict([
            ('inputs', nn.Linear(25088, 240)), 
            ('relu1', nn.ReLU()),
            ('dropout',nn.Dropout(0.5)),
            ('hidden_layer1', nn.Linear(240, 120)), 
            ('relu2',nn.ReLU()),
            ('hidden_layer2',nn.Linear(120,80)), 
            ('relu3',nn.ReLU()),
            ('hidden_layer3',nn.Linear(80,102)),
            ('output', nn.LogSoftmax(dim=1))]))
   
model.classifier = classifier
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.torch/models/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:05<00:00, 95983400.19it/s]

# %%
######TRAINING######
# Convert model to be used on GPU as we will use GPU power
if torch.cuda.is_available():
    model.cuda()
#Use Negative loss likelihood as it appropreciate for this type 
#of classification and use Adam optimizers as it give best result
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)

epochs=15
for epoch in range(epochs):
    print("Epoch: {}/{}".format(epoch+1, epochs))
    
    # Training
    model.train()
     
    # Set loss and accuracy to 0 and accremente
    loss_train = 0.0
    acc_train = 0.0
    
 
    for i, (inputs, labels) in enumerate(dataloaders["train"]):
 
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')
         
        # Reset every gradien on zero
        optimizer.zero_grad()
         
        # Forward 
        outputs = model(inputs)
         
        # get loss
        loss = criterion(outputs, labels)
         
        # Backpropagate the gradients and optimization
        loss.backward()
        optimizer.step()
         
        ########Stats parts#######
        loss_train += loss.item() * inputs.size(0)
        _, predictions = torch.max(outputs.data, 1)
        counts = predictions.eq(labels.data.view_as(predictions))
        acc = torch.mean(counts.type(torch.FloatTensor))
        acc_train += acc.item() * inputs.size(0)
        
        #print batch, loss and accuracy
        print("Batch no: {:04d}, Training loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))
# Out:
# Epoch: 1/15
# Batch no: 0000, Loss on trainig: 4.6563, Accuracy: 0.0000
# Batch no: 0001, Loss on trainig: 4.6456, Accuracy: 0.0000
# Batch no: 0002, Loss on trainig: 4.5225, Accuracy: 0.0000
# Batch no: 0003, Loss on trainig: 4.6884, Accuracy: 0.0156
# Batch no: 0004, Loss on trainig: 4.8093, Accuracy: 0.0469
# Batch no: 0005, Loss on trainig: 4.6221, Accuracy: 0.0156
# Batch no: 0006, Loss on trainig: 4.5805, Accuracy: 0.0156
# Batch no: 0007, Loss on trainig: 4.5631, Accuracy: 0.0156
# Batch no: 0008, Loss on trainig: 4.6408, Accuracy: 0.0156
# Batch no: 0009, Loss on trainig: 4.6482, Accuracy: 0.0312
# Batch no: 0010, Loss on trainig: 4.5612, Accuracy: 0.0625
# Batch no: 0011, Loss on trainig: 4.5689, Accuracy: 0.0312
# Batch no: 0012, Loss on trainig: 4.4542, Accuracy: 0.0625
# Batch no: 0013, Loss on trainig: 4.4564, Accuracy: 0.0469
# Batch no: 0014, Loss on trainig: 4.4678, Accuracy: 0.0156
# Batch no: 0015, Loss on trainig: 4.5959, Accuracy: 0.0156
# Batch no: 0016, Loss on trainig: 4.4966, Accuracy: 0.0312
# Batch no: 0017, Loss on trainig: 4.4505, Accuracy: 0.0781
# Batch no: 0018, Loss on trainig: 4.5484, Accuracy: 0.0312
# Batch no: 0019, Loss on trainig: 4.4584, Accuracy: 0.0156
# Batch no: 0020, Loss on trainig: 4.4053, Accuracy: 0.0625
# Batch no: 0021, Loss on trainig: 4.5884, Accuracy: 0.0625
# Batch no: 0022, Loss on trainig: 4.4679, Accuracy: 0.0156
# Batch no: 0023, Loss on trainig: 4.4978, Accuracy: 0.0000
# Batch no: 0024, Loss on trainig: 4.4559, Accuracy: 0.0156
# Batch no: 0025, Loss on trainig: 4.5235, Accuracy: 0.0156
# Batch no: 0026, Loss on trainig: 4.3747, Accuracy: 0.0781
# Batch no: 0027, Loss on trainig: 4.5034, Accuracy: 0.0312
# Batch no: 0028, Loss on trainig: 4.5836, Accuracy: 0.0625
# Batch no: 0029, Loss on trainig: 4.4589, Accuracy: 0.0312
# Batch no: 0030, Loss on trainig: 4.3968, Accuracy: 0.1250
# Batch no: 0031, Loss on trainig: 4.4199, Accuracy: 0.1094
# Batch no: 0032, Loss on trainig: 4.3828, Accuracy: 0.0938
# Batch no: 0033, Loss on trainig: 4.1723, Accuracy: 0.0938
# Batch no: 0034, Loss on trainig: 4.1868, Accuracy: 0.0781
# Batch no: 0035, Loss on trainig: 4.5937, Accuracy: 0.0156
# Batch no: 0036, Loss on trainig: 4.3333, Accuracy: 0.0781
# Batch no: 0037, Loss on trainig: 4.2331, Accuracy: 0.0938
# Batch no: 0038, Loss on trainig: 4.3511, Accuracy: 0.0469
# Batch no: 0039, Loss on trainig: 4.3242, Accuracy: 0.0469
# Batch no: 0040, Loss on trainig: 4.3593, Accuracy: 0.0781
# Batch no: 0041, Loss on trainig: 4.4113, Accuracy: 0.0625
# Batch no: 0042, Loss on trainig: 4.2277, Accuracy: 0.0625
# Batch no: 0043, Loss on trainig: 4.1555, Accuracy: 0.0781
# Batch no: 0044, Loss on trainig: 4.1813, Accuracy: 0.0938
# Batch no: 0045, Loss on trainig: 4.2837, Accuracy: 0.0938
# Batch no: 0046, Loss on trainig: 4.3630, Accuracy: 0.0781
# Batch no: 0047, Loss on trainig: 4.1140, Accuracy: 0.0938
# Batch no: 0048, Loss on trainig: 3.9827, Accuracy: 0.1250
# Batch no: 0049, Loss on trainig: 4.2397, Accuracy: 0.0312
# Batch no: 0050, Loss on trainig: 4.2691, Accuracy: 0.1094
# Batch no: 0051, Loss on trainig: 4.4028, Accuracy: 0.0625
# Batch no: 0052, Loss on trainig: 4.2269, Accuracy: 0.0625
# Batch no: 0053, Loss on trainig: 4.3325, Accuracy: 0.0469
# Batch no: 0054, Loss on trainig: 4.2407, Accuracy: 0.0469
# Batch no: 0055, Loss on trainig: 4.1441, Accuracy: 0.0781
# Batch no: 0056, Loss on trainig: 3.8579, Accuracy: 0.1719
# Batch no: 0057, Loss on trainig: 4.1918, Accuracy: 0.0625
# Batch no: 0058, Loss on trainig: 3.9868, Accuracy: 0.1094
# Batch no: 0059, Loss on trainig: 4.1649, Accuracy: 0.0938
# Batch no: 0060, Loss on trainig: 4.1723, Accuracy: 0.1094
# Batch no: 0061, Loss on trainig: 3.8593, Accuracy: 0.0938
# Batch no: 0062, Loss on trainig: 4.1123, Accuracy: 0.0781
# Batch no: 0063, Loss on trainig: 3.9615, Accuracy: 0.1094
# Batch no: 0064, Loss on trainig: 3.9179, Accuracy: 0.1406
# Batch no: 0065, Loss on trainig: 4.0684, Accuracy: 0.1250
# Batch no: 0066, Loss on trainig: 3.9085, Accuracy: 0.1094
# Batch no: 0067, Loss on trainig: 3.8475, Accuracy: 0.0625
# Batch no: 0068, Loss on trainig: 3.8938, Accuracy: 0.1250
# Batch no: 0069, Loss on trainig: 4.0307, Accuracy: 0.0625
# Batch no: 0070, Loss on trainig: 4.0095, Accuracy: 0.0469
# Batch no: 0071, Loss on trainig: 3.7474, Accuracy: 0.1875
# Batch no: 0072, Loss on trainig: 3.9227, Accuracy: 0.0781
# Batch no: 0073, Loss on trainig: 3.8399, Accuracy: 0.1562
# Batch no: 0074, Loss on trainig: 3.4935, Accuracy: 0.1406
# Batch no: 0075, Loss on trainig: 3.9280, Accuracy: 0.1250
# Batch no: 0076, Loss on trainig: 3.8456, Accuracy: 0.1562
# Batch no: 0077, Loss on trainig: 3.9678, Accuracy: 0.1250
# Batch no: 0078, Loss on trainig: 3.7304, Accuracy: 0.1719
# Batch no: 0079, Loss on trainig: 3.7700, Accuracy: 0.1250
# Batch no: 0080, Loss on trainig: 4.0139, Accuracy: 0.1094
# Batch no: 0081, Loss on trainig: 3.3267, Accuracy: 0.2500
# Batch no: 0082, Loss on trainig: 3.7012, Accuracy: 0.1094
# Batch no: 0083, Loss on trainig: 3.8866, Accuracy: 0.2031
# Batch no: 0084, Loss on trainig: 3.4516, Accuracy: 0.1562
# Batch no: 0085, Loss on trainig: 3.5803, Accuracy: 0.1719
# Batch no: 0086, Loss on trainig: 3.7892, Accuracy: 0.1406
# Batch no: 0087, Loss on trainig: 3.5615, Accuracy: 0.2500
# Batch no: 0088, Loss on trainig: 3.7059, Accuracy: 0.2188
# Batch no: 0089, Loss on trainig: 3.8887, Accuracy: 0.1250
# Batch no: 0090, Loss on trainig: 3.5924, Accuracy: 0.1719
# Batch no: 0091, Loss on trainig: 3.2467, Accuracy: 0.2500
# Batch no: 0092, Loss on trainig: 3.7760, Accuracy: 0.0938
# Batch no: 0093, Loss on trainig: 3.7740, Accuracy: 0.1562
# Batch no: 0094, Loss on trainig: 3.8216, Accuracy: 0.1875
# Batch no: 0095, Loss on trainig: 3.7198, Accuracy: 0.1719
# Batch no: 0096, Loss on trainig: 3.3701, Accuracy: 0.2344
# Batch no: 0097, Loss on trainig: 3.8406, Accuracy: 0.1094
# Batch no: 0098, Loss on trainig: 3.5149, Accuracy: 0.2031
# Batch no: 0099, Loss on trainig: 3.7196, Accuracy: 0.1250
# Batch no: 0100, Loss on trainig: 3.6225, Accuracy: 0.2344
# Batch no: 0101, Loss on trainig: 3.4431, Accuracy: 0.2188
# Batch no: 0102, Loss on trainig: 3.7273, Accuracy: 0.1250
# Epoch: 2/15
# Batch no: 0000, Loss on trainig: 3.1787, Accuracy: 0.2812
# Batch no: 0001, Loss on trainig: 3.3672, Accuracy: 0.1562
# Batch no: 0002, Loss on trainig: 3.6677, Accuracy: 0.1562
# Batch no: 0003, Loss on trainig: 3.1931, Accuracy: 0.2656
# Batch no: 0004, Loss on trainig: 3.2324, Accuracy: 0.1875
# Batch no: 0005, Loss on trainig: 3.1038, Accuracy: 0.2656
# Batch no: 0006, Loss on trainig: 3.2728, Accuracy: 0.2500
# Batch no: 0007, Loss on trainig: 3.2896, Accuracy: 0.2188
# Batch no: 0008, Loss on trainig: 3.3894, Accuracy: 0.1562
# Batch no: 0009, Loss on trainig: 3.2297, Accuracy: 0.2969
# Batch no: 0010, Loss on trainig: 3.3441, Accuracy: 0.2344
# Batch no: 0011, Loss on trainig: 3.0192, Accuracy: 0.2812
# Batch no: 0012, Loss on trainig: 3.3660, Accuracy: 0.2500
# Batch no: 0013, Loss on trainig: 3.2547, Accuracy: 0.2031
# Batch no: 0014, Loss on trainig: 3.1049, Accuracy: 0.2969
# Batch no: 0015, Loss on trainig: 3.1303, Accuracy: 0.2031
# Batch no: 0016, Loss on trainig: 3.2346, Accuracy: 0.2031
# Batch no: 0017, Loss on trainig: 3.1065, Accuracy: 0.2344
# Batch no: 0018, Loss on trainig: 2.8579, Accuracy: 0.2344
# Batch no: 0019, Loss on trainig: 3.1045, Accuracy: 0.2188
# Batch no: 0020, Loss on trainig: 3.5293, Accuracy: 0.1562
# Batch no: 0021, Loss on trainig: 3.1455, Accuracy: 0.2656
# Batch no: 0022, Loss on trainig: 3.1612, Accuracy: 0.2656
# Batch no: 0023, Loss on trainig: 3.0775, Accuracy: 0.2812
# Batch no: 0024, Loss on trainig: 3.0159, Accuracy: 0.2812
# Batch no: 0025, Loss on trainig: 3.3949, Accuracy: 0.1875
# Batch no: 0026, Loss on trainig: 3.2216, Accuracy: 0.1875
# Batch no: 0027, Loss on trainig: 2.8779, Accuracy: 0.2969
# Batch no: 0028, Loss on trainig: 3.3303, Accuracy: 0.2031
# Batch no: 0029, Loss on trainig: 3.3638, Accuracy: 0.1875
# Batch no: 0030, Loss on trainig: 3.3361, Accuracy: 0.2656
# Batch no: 0031, Loss on trainig: 3.0116, Accuracy: 0.2812
# Batch no: 0032, Loss on trainig: 3.0592, Accuracy: 0.1719
# Batch no: 0033, Loss on trainig: 3.1977, Accuracy: 0.2031
# Batch no: 0034, Loss on trainig: 2.7394, Accuracy: 0.3438
# Batch no: 0035, Loss on trainig: 2.8968, Accuracy: 0.3281
# Batch no: 0036, Loss on trainig: 3.5227, Accuracy: 0.1719
# Batch no: 0037, Loss on trainig: 3.2320, Accuracy: 0.2188
# Batch no: 0038, Loss on trainig: 2.8200, Accuracy: 0.3594
# Batch no: 0039, Loss on trainig: 2.7634, Accuracy: 0.3281
# Batch no: 0040, Loss on trainig: 2.9994, Accuracy: 0.2656
# Batch no: 0041, Loss on trainig: 3.0274, Accuracy: 0.2344
# Batch no: 0042, Loss on trainig: 3.0153, Accuracy: 0.2031
# Batch no: 0043, Loss on trainig: 3.0040, Accuracy: 0.2812
# Batch no: 0044, Loss on trainig: 2.8590, Accuracy: 0.3750
# Batch no: 0045, Loss on trainig: 3.1465, Accuracy: 0.2031
# Batch no: 0046, Loss on trainig: 2.8262, Accuracy: 0.2969
# Batch no: 0047, Loss on trainig: 3.0098, Accuracy: 0.2656
# Batch no: 0048, Loss on trainig: 3.1433, Accuracy: 0.1719
# Batch no: 0049, Loss on trainig: 2.8813, Accuracy: 0.3125
# Batch no: 0050, Loss on trainig: 2.8732, Accuracy: 0.2500
# Batch no: 0051, Loss on trainig: 2.9845, Accuracy: 0.2969
# Batch no: 0052, Loss on trainig: 2.9658, Accuracy: 0.2500
# Batch no: 0053, Loss on trainig: 2.6069, Accuracy: 0.2656
# Batch no: 0054, Loss on trainig: 2.7842, Accuracy: 0.2500
# Batch no: 0055, Loss on trainig: 2.9456, Accuracy: 0.2812
# Batch no: 0056, Loss on trainig: 2.7789, Accuracy: 0.3281
# Batch no: 0057, Loss on trainig: 2.8788, Accuracy: 0.2969
# Batch no: 0058, Loss on trainig: 2.4977, Accuracy: 0.3594
# Batch no: 0059, Loss on trainig: 2.9303, Accuracy: 0.2188
# Batch no: 0060, Loss on trainig: 2.8232, Accuracy: 0.3438
# Batch no: 0061, Loss on trainig: 2.5403, Accuracy: 0.3594
# Batch no: 0062, Loss on trainig: 2.7176, Accuracy: 0.3438
# Batch no: 0063, Loss on trainig: 2.6898, Accuracy: 0.3594
# Batch no: 0064, Loss on trainig: 3.0247, Accuracy: 0.2812
# Batch no: 0065, Loss on trainig: 2.9993, Accuracy: 0.2500
# Batch no: 0066, Loss on trainig: 2.6751, Accuracy: 0.2812
# Batch no: 0067, Loss on trainig: 2.7266, Accuracy: 0.2500
# Batch no: 0068, Loss on trainig: 2.6155, Accuracy: 0.2344
# Batch no: 0069, Loss on trainig: 3.3210, Accuracy: 0.1562
# Batch no: 0070, Loss on trainig: 2.6821, Accuracy: 0.2969
# Batch no: 0071, Loss on trainig: 3.1122, Accuracy: 0.2344
# Batch no: 0072, Loss on trainig: 2.9028, Accuracy: 0.2500
# Batch no: 0073, Loss on trainig: 2.8031, Accuracy: 0.3125
# Batch no: 0074, Loss on trainig: 2.9158, Accuracy: 0.2188
# Batch no: 0075, Loss on trainig: 2.8595, Accuracy: 0.2969
# Batch no: 0076, Loss on trainig: 2.6523, Accuracy: 0.2812
# Batch no: 0077, Loss on trainig: 2.9619, Accuracy: 0.3281
# Batch no: 0078, Loss on trainig: 3.0732, Accuracy: 0.2344
# Batch no: 0079, Loss on trainig: 2.6899, Accuracy: 0.3125
# Batch no: 0080, Loss on trainig: 2.9636, Accuracy: 0.2656
# Batch no: 0081, Loss on trainig: 2.5965, Accuracy: 0.2969
# Batch no: 0082, Loss on trainig: 2.6421, Accuracy: 0.3438
# Batch no: 0083, Loss on trainig: 2.8976, Accuracy: 0.2656
# Batch no: 0084, Loss on trainig: 2.9399, Accuracy: 0.3125
# Batch no: 0085, Loss on trainig: 2.6510, Accuracy: 0.3906
# Batch no: 0086, Loss on trainig: 2.6557, Accuracy: 0.2500
# Batch no: 0087, Loss on trainig: 2.8894, Accuracy: 0.3125
# Batch no: 0088, Loss on trainig: 2.4198, Accuracy: 0.3750
# Batch no: 0089, Loss on trainig: 2.5026, Accuracy: 0.3281
# Batch no: 0090, Loss on trainig: 2.5173, Accuracy: 0.3438
# Batch no: 0091, Loss on trainig: 2.2818, Accuracy: 0.3438
# Batch no: 0092, Loss on trainig: 2.7685, Accuracy: 0.2656
# Batch no: 0093, Loss on trainig: 2.8663, Accuracy: 0.2344
# Batch no: 0094, Loss on trainig: 2.6168, Accuracy: 0.2812
# Batch no: 0095, Loss on trainig: 2.6324, Accuracy: 0.2656
# Batch no: 0096, Loss on trainig: 2.9170, Accuracy: 0.2656
# Batch no: 0097, Loss on trainig: 2.9882, Accuracy: 0.1875
# Batch no: 0098, Loss on trainig: 2.5154, Accuracy: 0.4062
# Batch no: 0099, Loss on trainig: 2.8281, Accuracy: 0.2344
# Batch no: 0100, Loss on trainig: 2.4364, Accuracy: 0.2812
# Batch no: 0101, Loss on trainig: 3.0028, Accuracy: 0.2500
# Batch no: 0102, Loss on trainig: 2.3348, Accuracy: 0.4583
# Epoch: 3/15
# Batch no: 0000, Loss on trainig: 2.3935, Accuracy: 0.4219
# Batch no: 0001, Loss on trainig: 2.4513, Accuracy: 0.3594
# Batch no: 0002, Loss on trainig: 2.9283, Accuracy: 0.4219
# Batch no: 0003, Loss on trainig: 2.6195, Accuracy: 0.3438
# Batch no: 0004, Loss on trainig: 2.6149, Accuracy: 0.3125
# Batch no: 0005, Loss on trainig: 2.5043, Accuracy: 0.3125
# Batch no: 0006, Loss on trainig: 2.8875, Accuracy: 0.3438
# Batch no: 0007, Loss on trainig: 2.6413, Accuracy: 0.2969
# Batch no: 0008, Loss on trainig: 2.4257, Accuracy: 0.3750
# Batch no: 0009, Loss on trainig: 2.7998, Accuracy: 0.2500
# Batch no: 0010, Loss on trainig: 3.0177, Accuracy: 0.2031
# Batch no: 0011, Loss on trainig: 2.4129, Accuracy: 0.3438
# Batch no: 0012, Loss on trainig: 2.6939, Accuracy: 0.3125
# Batch no: 0013, Loss on trainig: 2.3854, Accuracy: 0.3594
# Batch no: 0014, Loss on trainig: 2.2655, Accuracy: 0.4531
# Batch no: 0015, Loss on trainig: 2.2803, Accuracy: 0.2969
# Batch no: 0016, Loss on trainig: 2.3698, Accuracy: 0.3438
# Batch no: 0017, Loss on trainig: 2.7300, Accuracy: 0.3125
# Batch no: 0018, Loss on trainig: 2.6900, Accuracy: 0.2812
# Batch no: 0019, Loss on trainig: 2.7249, Accuracy: 0.2969
# Batch no: 0020, Loss on trainig: 2.5084, Accuracy: 0.3438
# Batch no: 0021, Loss on trainig: 2.5004, Accuracy: 0.3594
# Batch no: 0022, Loss on trainig: 2.9054, Accuracy: 0.2344
# Batch no: 0023, Loss on trainig: 2.6902, Accuracy: 0.2812
# Batch no: 0024, Loss on trainig: 2.8245, Accuracy: 0.3750
# Batch no: 0025, Loss on trainig: 2.9268, Accuracy: 0.2812
# Batch no: 0026, Loss on trainig: 2.5509, Accuracy: 0.3438
# Batch no: 0027, Loss on trainig: 2.2796, Accuracy: 0.4062
# Batch no: 0028, Loss on trainig: 2.5676, Accuracy: 0.2500
# Batch no: 0029, Loss on trainig: 2.2926, Accuracy: 0.3750
# Batch no: 0030, Loss on trainig: 2.5480, Accuracy: 0.3281
# Batch no: 0031, Loss on trainig: 2.7211, Accuracy: 0.3281
# Batch no: 0032, Loss on trainig: 2.7331, Accuracy: 0.3125
# Batch no: 0033, Loss on trainig: 2.5588, Accuracy: 0.3125
# Batch no: 0034, Loss on trainig: 2.7334, Accuracy: 0.3438
# Batch no: 0035, Loss on trainig: 2.5580, Accuracy: 0.3281
# Batch no: 0036, Loss on trainig: 2.7506, Accuracy: 0.2812
# Batch no: 0037, Loss on trainig: 2.1583, Accuracy: 0.4219
# Batch no: 0038, Loss on trainig: 2.3190, Accuracy: 0.4375
# Batch no: 0039, Loss on trainig: 2.5748, Accuracy: 0.4219
# Batch no: 0040, Loss on trainig: 2.3293, Accuracy: 0.3750
# Batch no: 0041, Loss on trainig: 2.6987, Accuracy: 0.3906
# Batch no: 0042, Loss on trainig: 2.6407, Accuracy: 0.2812
# Batch no: 0043, Loss on trainig: 2.5424, Accuracy: 0.3281
# Batch no: 0044, Loss on trainig: 2.2170, Accuracy: 0.3906
# Batch no: 0045, Loss on trainig: 2.3031, Accuracy: 0.4062
# Batch no: 0046, Loss on trainig: 2.4969, Accuracy: 0.3594
# Batch no: 0047, Loss on trainig: 2.6691, Accuracy: 0.3281
# Batch no: 0048, Loss on trainig: 2.8667, Accuracy: 0.2031
# Batch no: 0049, Loss on trainig: 2.4992, Accuracy: 0.2969
# Batch no: 0050, Loss on trainig: 2.5384, Accuracy: 0.3750
# Batch no: 0051, Loss on trainig: 2.4463, Accuracy: 0.2969
# Batch no: 0052, Loss on trainig: 2.7784, Accuracy: 0.3281
# Batch no: 0053, Loss on trainig: 2.4696, Accuracy: 0.4375
# Batch no: 0054, Loss on trainig: 2.3871, Accuracy: 0.2656
# Batch no: 0055, Loss on trainig: 2.3157, Accuracy: 0.3438
# Batch no: 0056, Loss on trainig: 2.3476, Accuracy: 0.3281
# Batch no: 0057, Loss on trainig: 2.0624, Accuracy: 0.4844
# Batch no: 0058, Loss on trainig: 2.8159, Accuracy: 0.2500
# Batch no: 0059, Loss on trainig: 2.5291, Accuracy: 0.3750
# Batch no: 0060, Loss on trainig: 2.5353, Accuracy: 0.3750
# Batch no: 0061, Loss on trainig: 2.6375, Accuracy: 0.3125
# Batch no: 0062, Loss on trainig: 3.0059, Accuracy: 0.1719
# Batch no: 0063, Loss on trainig: 2.1942, Accuracy: 0.3906
# Batch no: 0064, Loss on trainig: 2.2170, Accuracy: 0.3438
# Batch no: 0065, Loss on trainig: 2.3142, Accuracy: 0.3438
# Batch no: 0066, Loss on trainig: 2.0962, Accuracy: 0.4531
# Batch no: 0067, Loss on trainig: 2.8414, Accuracy: 0.3281
# Batch no: 0068, Loss on trainig: 2.2850, Accuracy: 0.3438
# Batch no: 0069, Loss on trainig: 2.2725, Accuracy: 0.4375
# Batch no: 0070, Loss on trainig: 2.5309, Accuracy: 0.2969
# Batch no: 0071, Loss on trainig: 2.4009, Accuracy: 0.3750
# Batch no: 0072, Loss on trainig: 2.6634, Accuracy: 0.3438
# Batch no: 0073, Loss on trainig: 2.0846, Accuracy: 0.5156
# Batch no: 0074, Loss on trainig: 2.7626, Accuracy: 0.2656
# Batch no: 0075, Loss on trainig: 2.3228, Accuracy: 0.4844
# Batch no: 0076, Loss on trainig: 2.0007, Accuracy: 0.3750
# Batch no: 0077, Loss on trainig: 2.4261, Accuracy: 0.4375
# Batch no: 0078, Loss on trainig: 2.1210, Accuracy: 0.4219
# Batch no: 0079, Loss on trainig: 2.8386, Accuracy: 0.3125
# Batch no: 0080, Loss on trainig: 2.6322, Accuracy: 0.3125
# Batch no: 0081, Loss on trainig: 2.1973, Accuracy: 0.3906
# Batch no: 0082, Loss on trainig: 2.2487, Accuracy: 0.3594
# Batch no: 0083, Loss on trainig: 1.9834, Accuracy: 0.4688
# Batch no: 0084, Loss on trainig: 2.3835, Accuracy: 0.4062
# Batch no: 0085, Loss on trainig: 2.0253, Accuracy: 0.4375
# Batch no: 0086, Loss on trainig: 2.3950, Accuracy: 0.3281
# Batch no: 0087, Loss on trainig: 2.2375, Accuracy: 0.4062
# Batch no: 0088, Loss on trainig: 2.2935, Accuracy: 0.2656
# Batch no: 0089, Loss on trainig: 2.2790, Accuracy: 0.4062
# Batch no: 0090, Loss on trainig: 2.2901, Accuracy: 0.4375
# Batch no: 0091, Loss on trainig: 2.2878, Accuracy: 0.4375
# Batch no: 0092, Loss on trainig: 2.1459, Accuracy: 0.4531
# Batch no: 0093, Loss on trainig: 2.5853, Accuracy: 0.3906
# Batch no: 0094, Loss on trainig: 2.0770, Accuracy: 0.4219
# Batch no: 0095, Loss on trainig: 2.2968, Accuracy: 0.3906
# Batch no: 0096, Loss on trainig: 2.3266, Accuracy: 0.4062
# Batch no: 0097, Loss on trainig: 2.4557, Accuracy: 0.4062
# Batch no: 0098, Loss on trainig: 2.2375, Accuracy: 0.3438
# Batch no: 0099, Loss on trainig: 2.1579, Accuracy: 0.4531
# Batch no: 0100, Loss on trainig: 2.4043, Accuracy: 0.3281
# Batch no: 0101, Loss on trainig: 2.3566, Accuracy: 0.3906
# Batch no: 0102, Loss on trainig: 2.5464, Accuracy: 0.3750
# Epoch: 4/15
# Batch no: 0000, Loss on trainig: 2.4236, Accuracy: 0.3594
# Batch no: 0001, Loss on trainig: 2.0019, Accuracy: 0.4219
# Batch no: 0002, Loss on trainig: 1.9941, Accuracy: 0.3750
# Batch no: 0003, Loss on trainig: 2.8027, Accuracy: 0.2031
# Batch no: 0004, Loss on trainig: 1.9950, Accuracy: 0.4375
# Batch no: 0005, Loss on trainig: 2.0778, Accuracy: 0.4688
# Batch no: 0006, Loss on trainig: 2.1144, Accuracy: 0.4375
# Batch no: 0007, Loss on trainig: 2.3172, Accuracy: 0.3125
# Batch no: 0008, Loss on trainig: 2.4065, Accuracy: 0.4219
# Batch no: 0009, Loss on trainig: 1.9334, Accuracy: 0.4688
# Batch no: 0010, Loss on trainig: 2.2402, Accuracy: 0.4375
# Batch no: 0011, Loss on trainig: 2.5178, Accuracy: 0.3750
# Batch no: 0012, Loss on trainig: 2.4615, Accuracy: 0.3594
# Batch no: 0013, Loss on trainig: 2.5468, Accuracy: 0.3594
# Batch no: 0014, Loss on trainig: 2.3914, Accuracy: 0.2969
# Batch no: 0015, Loss on trainig: 2.3288, Accuracy: 0.3594
# Batch no: 0016, Loss on trainig: 2.0782, Accuracy: 0.4219
# Batch no: 0017, Loss on trainig: 2.1540, Accuracy: 0.4062
# Batch no: 0018, Loss on trainig: 2.3059, Accuracy: 0.3438
# Batch no: 0019, Loss on trainig: 2.3748, Accuracy: 0.4531
# Batch no: 0020, Loss on trainig: 2.0984, Accuracy: 0.4219
# Batch no: 0021, Loss on trainig: 2.2183, Accuracy: 0.4844
# Batch no: 0022, Loss on trainig: 2.2614, Accuracy: 0.3594
# Batch no: 0023, Loss on trainig: 2.1276, Accuracy: 0.4531
# Batch no: 0024, Loss on trainig: 1.9762, Accuracy: 0.3906
# Batch no: 0025, Loss on trainig: 2.2036, Accuracy: 0.3750
# Batch no: 0026, Loss on trainig: 2.3909, Accuracy: 0.3906
# Batch no: 0027, Loss on trainig: 2.3267, Accuracy: 0.4062
# Batch no: 0028, Loss on trainig: 2.1394, Accuracy: 0.4375
# Batch no: 0029, Loss on trainig: 2.0867, Accuracy: 0.4531
# Batch no: 0030, Loss on trainig: 2.4329, Accuracy: 0.3750
# Batch no: 0031, Loss on trainig: 2.3148, Accuracy: 0.3594
# Batch no: 0032, Loss on trainig: 2.3721, Accuracy: 0.4062
# Batch no: 0033, Loss on trainig: 2.2479, Accuracy: 0.5156
# Batch no: 0034, Loss on trainig: 2.1132, Accuracy: 0.4375
# Batch no: 0035, Loss on trainig: 2.4088, Accuracy: 0.3438
# Batch no: 0036, Loss on trainig: 2.0580, Accuracy: 0.4688
# Batch no: 0037, Loss on trainig: 2.4952, Accuracy: 0.2969
# Batch no: 0038, Loss on trainig: 2.7975, Accuracy: 0.2500
# Batch no: 0039, Loss on trainig: 2.3703, Accuracy: 0.3438
# Batch no: 0040, Loss on trainig: 2.2430, Accuracy: 0.3750
# Batch no: 0041, Loss on trainig: 2.3027, Accuracy: 0.3906
# Batch no: 0042, Loss on trainig: 2.4394, Accuracy: 0.3281
# Batch no: 0043, Loss on trainig: 2.4945, Accuracy: 0.3281
# Batch no: 0044, Loss on trainig: 2.5995, Accuracy: 0.2969
# Batch no: 0045, Loss on trainig: 2.1516, Accuracy: 0.4219
# Batch no: 0046, Loss on trainig: 2.3664, Accuracy: 0.3125
# Batch no: 0047, Loss on trainig: 2.4337, Accuracy: 0.4062
# Batch no: 0048, Loss on trainig: 2.2366, Accuracy: 0.3906
# Batch no: 0049, Loss on trainig: 2.1985, Accuracy: 0.4062
# Batch no: 0050, Loss on trainig: 2.0277, Accuracy: 0.5000
# Batch no: 0051, Loss on trainig: 2.7454, Accuracy: 0.2344
# Batch no: 0052, Loss on trainig: 2.1128, Accuracy: 0.4375
# Batch no: 0053, Loss on trainig: 2.1390, Accuracy: 0.2969
# Batch no: 0054, Loss on trainig: 2.2924, Accuracy: 0.4375
# Batch no: 0055, Loss on trainig: 1.9502, Accuracy: 0.4844
# Batch no: 0056, Loss on trainig: 2.4779, Accuracy: 0.2969
# Batch no: 0057, Loss on trainig: 2.3874, Accuracy: 0.4375
# Batch no: 0058, Loss on trainig: 2.4141, Accuracy: 0.4531
# Batch no: 0059, Loss on trainig: 2.0559, Accuracy: 0.4375
# Batch no: 0060, Loss on trainig: 2.1864, Accuracy: 0.4375
# Batch no: 0061, Loss on trainig: 2.1093, Accuracy: 0.4375
# Batch no: 0062, Loss on trainig: 2.0745, Accuracy: 0.4062
# Batch no: 0063, Loss on trainig: 2.6834, Accuracy: 0.3750
# Batch no: 0064, Loss on trainig: 2.1605, Accuracy: 0.3750
# Batch no: 0065, Loss on trainig: 2.6209, Accuracy: 0.2969
# Batch no: 0066, Loss on trainig: 2.2857, Accuracy: 0.4062
# Batch no: 0067, Loss on trainig: 2.5502, Accuracy: 0.3438
# Batch no: 0068, Loss on trainig: 2.1417, Accuracy: 0.3906
# Batch no: 0069, Loss on trainig: 2.4916, Accuracy: 0.3125
# Batch no: 0070, Loss on trainig: 2.2921, Accuracy: 0.3750
# Batch no: 0071, Loss on trainig: 1.9255, Accuracy: 0.4688
# Batch no: 0072, Loss on trainig: 2.3976, Accuracy: 0.3438
# Batch no: 0073, Loss on trainig: 2.2525, Accuracy: 0.4531
# Batch no: 0074, Loss on trainig: 2.1349, Accuracy: 0.4375
# Batch no: 0075, Loss on trainig: 2.1017, Accuracy: 0.4375
# Batch no: 0076, Loss on trainig: 2.3025, Accuracy: 0.3438
# Batch no: 0077, Loss on trainig: 2.2673, Accuracy: 0.4531
# Batch no: 0078, Loss on trainig: 2.4635, Accuracy: 0.3906
# Batch no: 0079, Loss on trainig: 2.2618, Accuracy: 0.3125
# Batch no: 0080, Loss on trainig: 2.1416, Accuracy: 0.4062
# Batch no: 0081, Loss on trainig: 2.0700, Accuracy: 0.4531
# Batch no: 0082, Loss on trainig: 2.2784, Accuracy: 0.3906
# Batch no: 0083, Loss on trainig: 2.7099, Accuracy: 0.3125
# Batch no: 0084, Loss on trainig: 2.2023, Accuracy: 0.4688
# Batch no: 0085, Loss on trainig: 2.1018, Accuracy: 0.5000
# Batch no: 0086, Loss on trainig: 2.0759, Accuracy: 0.4844
# Batch no: 0087, Loss on trainig: 2.1497, Accuracy: 0.4219
# Batch no: 0088, Loss on trainig: 1.9929, Accuracy: 0.4531
# Batch no: 0089, Loss on trainig: 1.9149, Accuracy: 0.5156
# Batch no: 0090, Loss on trainig: 2.5103, Accuracy: 0.3281
# Batch no: 0091, Loss on trainig: 2.1278, Accuracy: 0.4531
# Batch no: 0092, Loss on trainig: 1.8541, Accuracy: 0.5000
# Batch no: 0093, Loss on trainig: 1.6676, Accuracy: 0.4844
# Batch no: 0094, Loss on trainig: 1.6758, Accuracy: 0.5312
# Batch no: 0095, Loss on trainig: 2.2529, Accuracy: 0.4375
# Batch no: 0096, Loss on trainig: 2.4251, Accuracy: 0.3906
# Batch no: 0097, Loss on trainig: 2.2100, Accuracy: 0.4375
# Batch no: 0098, Loss on trainig: 2.3179, Accuracy: 0.3281
# Batch no: 0099, Loss on trainig: 2.2274, Accuracy: 0.3906
# Batch no: 0100, Loss on trainig: 2.1873, Accuracy: 0.3438
# Batch no: 0101, Loss on trainig: 2.0678, Accuracy: 0.3906
# Batch no: 0102, Loss on trainig: 2.2701, Accuracy: 0.3750
# Epoch: 5/15
# Batch no: 0000, Loss on trainig: 2.1639, Accuracy: 0.4062
# Batch no: 0001, Loss on trainig: 2.0942, Accuracy: 0.4219
# Batch no: 0002, Loss on trainig: 2.1409, Accuracy: 0.3594
# Batch no: 0003, Loss on trainig: 2.2766, Accuracy: 0.3750
# Batch no: 0004, Loss on trainig: 2.1657, Accuracy: 0.4375
# Batch no: 0005, Loss on trainig: 2.4175, Accuracy: 0.3750
# Batch no: 0006, Loss on trainig: 2.1196, Accuracy: 0.4375
# Batch no: 0007, Loss on trainig: 2.0434, Accuracy: 0.5156
# Batch no: 0008, Loss on trainig: 1.8125, Accuracy: 0.5312
# Batch no: 0009, Loss on trainig: 2.1953, Accuracy: 0.3750
# Batch no: 0010, Loss on trainig: 1.8934, Accuracy: 0.5469
# Batch no: 0011, Loss on trainig: 2.4893, Accuracy: 0.2969
# Batch no: 0012, Loss on trainig: 1.9684, Accuracy: 0.5156
# Batch no: 0013, Loss on trainig: 1.9037, Accuracy: 0.4844
# Batch no: 0014, Loss on trainig: 2.3758, Accuracy: 0.4062
# Batch no: 0015, Loss on trainig: 2.2090, Accuracy: 0.4062
# Batch no: 0016, Loss on trainig: 1.9438, Accuracy: 0.4531
# Batch no: 0017, Loss on trainig: 2.0076, Accuracy: 0.4219
# Batch no: 0018, Loss on trainig: 2.3202, Accuracy: 0.3594
# Batch no: 0019, Loss on trainig: 2.6524, Accuracy: 0.3281
# Batch no: 0020, Loss on trainig: 1.7993, Accuracy: 0.5312
# Batch no: 0021, Loss on trainig: 1.6961, Accuracy: 0.4844
# Batch no: 0022, Loss on trainig: 2.4380, Accuracy: 0.4062
# Batch no: 0023, Loss on trainig: 2.0517, Accuracy: 0.4062
# Batch no: 0024, Loss on trainig: 2.2151, Accuracy: 0.3594
# Batch no: 0025, Loss on trainig: 2.1423, Accuracy: 0.3906
# Batch no: 0026, Loss on trainig: 2.1321, Accuracy: 0.3750
# Batch no: 0027, Loss on trainig: 2.1053, Accuracy: 0.4219
# Batch no: 0028, Loss on trainig: 2.0092, Accuracy: 0.5156
# Batch no: 0029, Loss on trainig: 1.9449, Accuracy: 0.5625
# Batch no: 0030, Loss on trainig: 1.7442, Accuracy: 0.5000
# Batch no: 0031, Loss on trainig: 2.3379, Accuracy: 0.4062
# Batch no: 0032, Loss on trainig: 2.3638, Accuracy: 0.3125
# Batch no: 0033, Loss on trainig: 1.6649, Accuracy: 0.5938
# Batch no: 0034, Loss on trainig: 1.9322, Accuracy: 0.4844
# Batch no: 0035, Loss on trainig: 2.0684, Accuracy: 0.4219
# Batch no: 0036, Loss on trainig: 1.9549, Accuracy: 0.4375
# Batch no: 0037, Loss on trainig: 2.2269, Accuracy: 0.4062
# Batch no: 0038, Loss on trainig: 2.4168, Accuracy: 0.3594
# Batch no: 0039, Loss on trainig: 2.2830, Accuracy: 0.4219
# Batch no: 0040, Loss on trainig: 1.9290, Accuracy: 0.4062
# Batch no: 0041, Loss on trainig: 1.9291, Accuracy: 0.4844
# Batch no: 0042, Loss on trainig: 2.1866, Accuracy: 0.3906
# Batch no: 0043, Loss on trainig: 2.4136, Accuracy: 0.2656
# Batch no: 0044, Loss on trainig: 1.8073, Accuracy: 0.5156
# Batch no: 0045, Loss on trainig: 2.0185, Accuracy: 0.3594
# Batch no: 0046, Loss on trainig: 2.1368, Accuracy: 0.3281
# Batch no: 0047, Loss on trainig: 2.3540, Accuracy: 0.3281
# Batch no: 0048, Loss on trainig: 2.2730, Accuracy: 0.4219
# Batch no: 0049, Loss on trainig: 2.1122, Accuracy: 0.4688
# Batch no: 0050, Loss on trainig: 2.3115, Accuracy: 0.4688
# Batch no: 0051, Loss on trainig: 2.3093, Accuracy: 0.4219
# Batch no: 0052, Loss on trainig: 2.1852, Accuracy: 0.4219
# Batch no: 0053, Loss on trainig: 1.9069, Accuracy: 0.4844
# Batch no: 0054, Loss on trainig: 2.3820, Accuracy: 0.4062
# Batch no: 0055, Loss on trainig: 2.2766, Accuracy: 0.4531
# Batch no: 0056, Loss on trainig: 2.3256, Accuracy: 0.3594
# Batch no: 0057, Loss on trainig: 2.2858, Accuracy: 0.3438
# Batch no: 0058, Loss on trainig: 1.9518, Accuracy: 0.4531
# Batch no: 0059, Loss on trainig: 1.8938, Accuracy: 0.3906
# Batch no: 0060, Loss on trainig: 2.0492, Accuracy: 0.4844
# Batch no: 0061, Loss on trainig: 1.8297, Accuracy: 0.4844
# Batch no: 0062, Loss on trainig: 2.0953, Accuracy: 0.3906
# Batch no: 0063, Loss on trainig: 2.0906, Accuracy: 0.4531
# Batch no: 0064, Loss on trainig: 2.3666, Accuracy: 0.3750
# Batch no: 0065, Loss on trainig: 2.2328, Accuracy: 0.4219
# Batch no: 0066, Loss on trainig: 2.2646, Accuracy: 0.4375
# Batch no: 0067, Loss on trainig: 2.2021, Accuracy: 0.4844
# Batch no: 0068, Loss on trainig: 1.9727, Accuracy: 0.5000
# Batch no: 0069, Loss on trainig: 2.4691, Accuracy: 0.3594
# Batch no: 0070, Loss on trainig: 2.1640, Accuracy: 0.3906
# Batch no: 0071, Loss on trainig: 1.7450, Accuracy: 0.4844
# Batch no: 0072, Loss on trainig: 2.1832, Accuracy: 0.4062
# Batch no: 0073, Loss on trainig: 1.8979, Accuracy: 0.4688
# Batch no: 0074, Loss on trainig: 2.0066, Accuracy: 0.4531
# Batch no: 0075, Loss on trainig: 1.9169, Accuracy: 0.5000
# Batch no: 0076, Loss on trainig: 2.0022, Accuracy: 0.4219
# Batch no: 0077, Loss on trainig: 2.2326, Accuracy: 0.3750
# Batch no: 0078, Loss on trainig: 1.9223, Accuracy: 0.4688
# Batch no: 0079, Loss on trainig: 2.1115, Accuracy: 0.4219
# Batch no: 0080, Loss on trainig: 2.2889, Accuracy: 0.3594
# Batch no: 0081, Loss on trainig: 2.0817, Accuracy: 0.4531
# Batch no: 0082, Loss on trainig: 2.2154, Accuracy: 0.3594
# Batch no: 0083, Loss on trainig: 1.4513, Accuracy: 0.5625
# Batch no: 0084, Loss on trainig: 2.3930, Accuracy: 0.4375
# Batch no: 0085, Loss on trainig: 2.1453, Accuracy: 0.4062
# Batch no: 0086, Loss on trainig: 2.3143, Accuracy: 0.3906
# Batch no: 0087, Loss on trainig: 2.1755, Accuracy: 0.3125
# Batch no: 0088, Loss on trainig: 2.1449, Accuracy: 0.4375
# Batch no: 0089, Loss on trainig: 1.8599, Accuracy: 0.4688
# Batch no: 0090, Loss on trainig: 2.2097, Accuracy: 0.4688
# Batch no: 0091, Loss on trainig: 2.1278, Accuracy: 0.4062
# Batch no: 0092, Loss on trainig: 2.0237, Accuracy: 0.4375
# Batch no: 0093, Loss on trainig: 2.0787, Accuracy: 0.4375
# Batch no: 0094, Loss on trainig: 2.2451, Accuracy: 0.4219
# Batch no: 0095, Loss on trainig: 1.8059, Accuracy: 0.4531
# Batch no: 0096, Loss on trainig: 2.4923, Accuracy: 0.3438
# Batch no: 0097, Loss on trainig: 2.2487, Accuracy: 0.4375
# Batch no: 0098, Loss on trainig: 2.9459, Accuracy: 0.2500
# Batch no: 0099, Loss on trainig: 1.9472, Accuracy: 0.4375
# Batch no: 0100, Loss on trainig: 1.9287, Accuracy: 0.4531
# Batch no: 0101, Loss on trainig: 2.3684, Accuracy: 0.4062
# Batch no: 0102, Loss on trainig: 1.8250, Accuracy: 0.5833
# Epoch: 6/15
# Batch no: 0000, Loss on trainig: 2.0620, Accuracy: 0.4219
# Batch no: 0001, Loss on trainig: 2.2472, Accuracy: 0.4531
# Batch no: 0002, Loss on trainig: 2.1897, Accuracy: 0.4688
# Batch no: 0003, Loss on trainig: 2.1870, Accuracy: 0.4531
# Batch no: 0004, Loss on trainig: 2.3476, Accuracy: 0.4219
# Batch no: 0005, Loss on trainig: 1.9338, Accuracy: 0.5156
# Batch no: 0006, Loss on trainig: 1.9433, Accuracy: 0.4531
# Batch no: 0007, Loss on trainig: 2.3525, Accuracy: 0.3906
# Batch no: 0008, Loss on trainig: 2.3367, Accuracy: 0.3438
# Batch no: 0009, Loss on trainig: 2.3552, Accuracy: 0.4219
# Batch no: 0010, Loss on trainig: 1.7168, Accuracy: 0.5156
# Batch no: 0011, Loss on trainig: 2.0288, Accuracy: 0.4688
# Batch no: 0012, Loss on trainig: 1.9316, Accuracy: 0.4688
# Batch no: 0013, Loss on trainig: 2.2331, Accuracy: 0.4062
# Batch no: 0014, Loss on trainig: 1.8178, Accuracy: 0.5156
# Batch no: 0015, Loss on trainig: 1.8906, Accuracy: 0.4375
# Batch no: 0016, Loss on trainig: 2.0307, Accuracy: 0.4531
# Batch no: 0017, Loss on trainig: 2.2626, Accuracy: 0.4375
# Batch no: 0018, Loss on trainig: 1.8288, Accuracy: 0.4688
# Batch no: 0019, Loss on trainig: 1.7544, Accuracy: 0.5000
# Batch no: 0020, Loss on trainig: 1.9118, Accuracy: 0.4062
# Batch no: 0021, Loss on trainig: 1.6855, Accuracy: 0.5469
# Batch no: 0022, Loss on trainig: 1.7768, Accuracy: 0.5156
# Batch no: 0023, Loss on trainig: 2.0701, Accuracy: 0.4531
# Batch no: 0024, Loss on trainig: 2.4413, Accuracy: 0.4062
# Batch no: 0025, Loss on trainig: 2.1348, Accuracy: 0.4688
# Batch no: 0026, Loss on trainig: 1.9178, Accuracy: 0.4844
# Batch no: 0027, Loss on trainig: 1.5025, Accuracy: 0.5781
# Batch no: 0028, Loss on trainig: 1.7952, Accuracy: 0.5000
# Batch no: 0029, Loss on trainig: 1.9499, Accuracy: 0.4688
# Batch no: 0030, Loss on trainig: 2.2141, Accuracy: 0.4062
# Batch no: 0031, Loss on trainig: 2.0835, Accuracy: 0.4219
# Batch no: 0032, Loss on trainig: 2.3494, Accuracy: 0.4375
# Batch no: 0033, Loss on trainig: 2.0293, Accuracy: 0.5000
# Batch no: 0034, Loss on trainig: 2.3610, Accuracy: 0.3906
# Batch no: 0035, Loss on trainig: 2.0059, Accuracy: 0.4219
# Batch no: 0036, Loss on trainig: 1.8344, Accuracy: 0.5625
# Batch no: 0037, Loss on trainig: 2.0602, Accuracy: 0.4531
# Batch no: 0038, Loss on trainig: 2.1230, Accuracy: 0.3906
# Batch no: 0039, Loss on trainig: 2.0678, Accuracy: 0.4219
# Batch no: 0040, Loss on trainig: 1.8374, Accuracy: 0.4062
# Batch no: 0041, Loss on trainig: 2.4448, Accuracy: 0.3438
# Batch no: 0042, Loss on trainig: 1.7699, Accuracy: 0.4688
# Batch no: 0043, Loss on trainig: 2.1905, Accuracy: 0.4219
# Batch no: 0044, Loss on trainig: 1.8236, Accuracy: 0.4688
# Batch no: 0045, Loss on trainig: 1.8749, Accuracy: 0.5000
# Batch no: 0046, Loss on trainig: 2.1035, Accuracy: 0.4062
# Batch no: 0047, Loss on trainig: 2.4787, Accuracy: 0.3594
# Batch no: 0048, Loss on trainig: 2.4491, Accuracy: 0.3594
# Batch no: 0049, Loss on trainig: 1.9442, Accuracy: 0.5469
# Batch no: 0050, Loss on trainig: 1.8620, Accuracy: 0.5000
# Batch no: 0051, Loss on trainig: 2.0520, Accuracy: 0.3906
# Batch no: 0052, Loss on trainig: 1.9123, Accuracy: 0.5000
# Batch no: 0053, Loss on trainig: 2.0367, Accuracy: 0.4219
# Batch no: 0054, Loss on trainig: 1.8321, Accuracy: 0.5156
# Batch no: 0055, Loss on trainig: 1.9176, Accuracy: 0.5312
# Batch no: 0056, Loss on trainig: 2.2371, Accuracy: 0.4375
# Batch no: 0057, Loss on trainig: 2.0205, Accuracy: 0.4531
# Batch no: 0058, Loss on trainig: 2.1020, Accuracy: 0.4688
# Batch no: 0059, Loss on trainig: 1.7778, Accuracy: 0.5156
# Batch no: 0060, Loss on trainig: 2.1843, Accuracy: 0.4219
# Batch no: 0061, Loss on trainig: 1.9919, Accuracy: 0.4219
# Batch no: 0062, Loss on trainig: 2.4561, Accuracy: 0.3125
# Batch no: 0063, Loss on trainig: 1.7904, Accuracy: 0.5000
# Batch no: 0064, Loss on trainig: 1.6242, Accuracy: 0.5625
# Batch no: 0065, Loss on trainig: 1.9945, Accuracy: 0.4062
# Batch no: 0066, Loss on trainig: 2.0617, Accuracy: 0.4844
# Batch no: 0067, Loss on trainig: 1.8805, Accuracy: 0.4375
# Batch no: 0068, Loss on trainig: 2.2423, Accuracy: 0.3750
# Batch no: 0069, Loss on trainig: 1.8704, Accuracy: 0.4688
# Batch no: 0070, Loss on trainig: 1.8904, Accuracy: 0.4688
# Batch no: 0071, Loss on trainig: 1.9119, Accuracy: 0.5156
# Batch no: 0072, Loss on trainig: 2.1929, Accuracy: 0.4062
# Batch no: 0073, Loss on trainig: 2.1059, Accuracy: 0.4688
# Batch no: 0074, Loss on trainig: 1.9465, Accuracy: 0.4062
# Batch no: 0075, Loss on trainig: 1.7204, Accuracy: 0.4688
# Batch no: 0076, Loss on trainig: 1.8337, Accuracy: 0.5469
# Batch no: 0077, Loss on trainig: 2.1982, Accuracy: 0.4375
# Batch no: 0078, Loss on trainig: 2.1535, Accuracy: 0.4375
# Batch no: 0079, Loss on trainig: 1.9374, Accuracy: 0.5625
# Batch no: 0080, Loss on trainig: 1.7979, Accuracy: 0.5469
# Batch no: 0081, Loss on trainig: 1.9195, Accuracy: 0.4375
# Batch no: 0082, Loss on trainig: 1.7437, Accuracy: 0.5469
# Batch no: 0083, Loss on trainig: 2.0038, Accuracy: 0.4844
# Batch no: 0084, Loss on trainig: 1.9602, Accuracy: 0.4844
# Batch no: 0085, Loss on trainig: 1.5841, Accuracy: 0.5469
# Batch no: 0086, Loss on trainig: 2.1169, Accuracy: 0.4531
# Batch no: 0087, Loss on trainig: 2.1542, Accuracy: 0.4844
# Batch no: 0088, Loss on trainig: 2.0004, Accuracy: 0.4062
# Batch no: 0089, Loss on trainig: 2.3680, Accuracy: 0.3750
# Batch no: 0090, Loss on trainig: 1.6811, Accuracy: 0.5312
# Batch no: 0091, Loss on trainig: 1.9847, Accuracy: 0.5156
# Batch no: 0092, Loss on trainig: 1.7917, Accuracy: 0.5156
# Batch no: 0093, Loss on trainig: 1.7844, Accuracy: 0.4219
# Batch no: 0094, Loss on trainig: 1.6829, Accuracy: 0.5156
# Batch no: 0095, Loss on trainig: 1.7336, Accuracy: 0.5625
# Batch no: 0096, Loss on trainig: 1.8099, Accuracy: 0.5625
# Batch no: 0097, Loss on trainig: 2.4716, Accuracy: 0.3594
# Batch no: 0098, Loss on trainig: 2.0769, Accuracy: 0.4531
# Batch no: 0099, Loss on trainig: 1.9399, Accuracy: 0.3906
# Batch no: 0100, Loss on trainig: 2.0201, Accuracy: 0.4531
# Batch no: 0101, Loss on trainig: 1.8373, Accuracy: 0.5000
# Batch no: 0102, Loss on trainig: 1.7165, Accuracy: 0.4583
# Epoch: 7/15
# Batch no: 0000, Loss on trainig: 1.6591, Accuracy: 0.6250
# Batch no: 0001, Loss on trainig: 1.5889, Accuracy: 0.5312
# Batch no: 0002, Loss on trainig: 1.9893, Accuracy: 0.4844
# Batch no: 0003, Loss on trainig: 1.7545, Accuracy: 0.4688
# Batch no: 0004, Loss on trainig: 1.8528, Accuracy: 0.5312
# Batch no: 0005, Loss on trainig: 1.6384, Accuracy: 0.5156
# Batch no: 0006, Loss on trainig: 2.4705, Accuracy: 0.3906
# Batch no: 0007, Loss on trainig: 1.6662, Accuracy: 0.6250
# Batch no: 0008, Loss on trainig: 1.7529, Accuracy: 0.4375
# Batch no: 0009, Loss on trainig: 1.7299, Accuracy: 0.5625
# Batch no: 0010, Loss on trainig: 2.1733, Accuracy: 0.4219
# Batch no: 0011, Loss on trainig: 1.9872, Accuracy: 0.4375
# Batch no: 0012, Loss on trainig: 1.9816, Accuracy: 0.5000
# Batch no: 0013, Loss on trainig: 1.6469, Accuracy: 0.5781
# Batch no: 0014, Loss on trainig: 1.9799, Accuracy: 0.4844
# Batch no: 0015, Loss on trainig: 2.4476, Accuracy: 0.4062
# Batch no: 0016, Loss on trainig: 2.0542, Accuracy: 0.4844
# Batch no: 0017, Loss on trainig: 2.1629, Accuracy: 0.3281
# Batch no: 0018, Loss on trainig: 2.0413, Accuracy: 0.3906
# Batch no: 0019, Loss on trainig: 1.8051, Accuracy: 0.4531
# Batch no: 0020, Loss on trainig: 2.0390, Accuracy: 0.4688
# Batch no: 0021, Loss on trainig: 2.1803, Accuracy: 0.4375
# Batch no: 0022, Loss on trainig: 1.9149, Accuracy: 0.4844
# Batch no: 0023, Loss on trainig: 1.6852, Accuracy: 0.5625
# Batch no: 0024, Loss on trainig: 1.7235, Accuracy: 0.4531
# Batch no: 0025, Loss on trainig: 1.8770, Accuracy: 0.5469
# Batch no: 0026, Loss on trainig: 1.5844, Accuracy: 0.5000
# Batch no: 0027, Loss on trainig: 1.9334, Accuracy: 0.4844
# Batch no: 0028, Loss on trainig: 1.8452, Accuracy: 0.5000
# Batch no: 0029, Loss on trainig: 1.6751, Accuracy: 0.4844
# Batch no: 0030, Loss on trainig: 2.3416, Accuracy: 0.3750
# Batch no: 0031, Loss on trainig: 2.0219, Accuracy: 0.4219
# Batch no: 0032, Loss on trainig: 2.1429, Accuracy: 0.4062
# Batch no: 0033, Loss on trainig: 2.1304, Accuracy: 0.3906
# Batch no: 0034, Loss on trainig: 1.5444, Accuracy: 0.6406
# Batch no: 0035, Loss on trainig: 1.7829, Accuracy: 0.4688
# Batch no: 0036, Loss on trainig: 2.2615, Accuracy: 0.3906
# Batch no: 0037, Loss on trainig: 1.5766, Accuracy: 0.6094
# Batch no: 0038, Loss on trainig: 2.1188, Accuracy: 0.4688
# Batch no: 0039, Loss on trainig: 2.3795, Accuracy: 0.4062
# Batch no: 0040, Loss on trainig: 2.0698, Accuracy: 0.4375
# Batch no: 0041, Loss on trainig: 1.7222, Accuracy: 0.4531
# Batch no: 0042, Loss on trainig: 2.5348, Accuracy: 0.3438
# Batch no: 0043, Loss on trainig: 2.0726, Accuracy: 0.4531
# Batch no: 0044, Loss on trainig: 1.5323, Accuracy: 0.6250
# Batch no: 0045, Loss on trainig: 1.8198, Accuracy: 0.5469
# Batch no: 0046, Loss on trainig: 1.6741, Accuracy: 0.5156
# Batch no: 0047, Loss on trainig: 2.1575, Accuracy: 0.4531
# Batch no: 0048, Loss on trainig: 1.8306, Accuracy: 0.4375
# Batch no: 0049, Loss on trainig: 2.0071, Accuracy: 0.4688
# Batch no: 0050, Loss on trainig: 2.2484, Accuracy: 0.5000
# Batch no: 0051, Loss on trainig: 1.8511, Accuracy: 0.4688
# Batch no: 0052, Loss on trainig: 1.9325, Accuracy: 0.5781
# Batch no: 0053, Loss on trainig: 2.0145, Accuracy: 0.4062
# Batch no: 0054, Loss on trainig: 2.2205, Accuracy: 0.3750
# Batch no: 0055, Loss on trainig: 1.7460, Accuracy: 0.5156
# Batch no: 0056, Loss on trainig: 2.1934, Accuracy: 0.4062
# Batch no: 0057, Loss on trainig: 2.0463, Accuracy: 0.4219
# Batch no: 0058, Loss on trainig: 1.7400, Accuracy: 0.4688
# Batch no: 0059, Loss on trainig: 2.0488, Accuracy: 0.4531
# Batch no: 0060, Loss on trainig: 1.9993, Accuracy: 0.4375
# Batch no: 0061, Loss on trainig: 1.8694, Accuracy: 0.4531
# Batch no: 0062, Loss on trainig: 1.6688, Accuracy: 0.5312
# Batch no: 0063, Loss on trainig: 1.7460, Accuracy: 0.5781
# Batch no: 0064, Loss on trainig: 2.2873, Accuracy: 0.3906
# Batch no: 0065, Loss on trainig: 1.6653, Accuracy: 0.5469
# Batch no: 0066, Loss on trainig: 2.0159, Accuracy: 0.4844
# Batch no: 0067, Loss on trainig: 2.1104, Accuracy: 0.4531
# Batch no: 0068, Loss on trainig: 1.7297, Accuracy: 0.5156
# Batch no: 0069, Loss on trainig: 2.0652, Accuracy: 0.5000
# Batch no: 0070, Loss on trainig: 2.1968, Accuracy: 0.3906
# Batch no: 0071, Loss on trainig: 1.7740, Accuracy: 0.4688
# Batch no: 0072, Loss on trainig: 1.7571, Accuracy: 0.5312
# Batch no: 0073, Loss on trainig: 1.9881, Accuracy: 0.4219
# Batch no: 0074, Loss on trainig: 1.7137, Accuracy: 0.5312
# Batch no: 0075, Loss on trainig: 1.6473, Accuracy: 0.5312
# Batch no: 0076, Loss on trainig: 1.8937, Accuracy: 0.5625
# Batch no: 0077, Loss on trainig: 1.8831, Accuracy: 0.5156
# Batch no: 0078, Loss on trainig: 2.0677, Accuracy: 0.4531
# Batch no: 0079, Loss on trainig: 1.5875, Accuracy: 0.5000
# Batch no: 0080, Loss on trainig: 1.9089, Accuracy: 0.5156
# Batch no: 0081, Loss on trainig: 1.8872, Accuracy: 0.5000
# Batch no: 0082, Loss on trainig: 2.2059, Accuracy: 0.4531
# Batch no: 0083, Loss on trainig: 1.9571, Accuracy: 0.4062
# Batch no: 0084, Loss on trainig: 2.0849, Accuracy: 0.5312
# Batch no: 0085, Loss on trainig: 1.5795, Accuracy: 0.5469
# Batch no: 0086, Loss on trainig: 1.4674, Accuracy: 0.6094
# Batch no: 0087, Loss on trainig: 1.9402, Accuracy: 0.4375
# Batch no: 0088, Loss on trainig: 1.9709, Accuracy: 0.4375
# Batch no: 0089, Loss on trainig: 1.9080, Accuracy: 0.4844
# Batch no: 0090, Loss on trainig: 1.6773, Accuracy: 0.5781
# Batch no: 0091, Loss on trainig: 2.1073, Accuracy: 0.4219
# Batch no: 0092, Loss on trainig: 1.9852, Accuracy: 0.3906
# Batch no: 0093, Loss on trainig: 1.8455, Accuracy: 0.4688
# Batch no: 0094, Loss on trainig: 2.1709, Accuracy: 0.4531
# Batch no: 0095, Loss on trainig: 1.7149, Accuracy: 0.5938
# Batch no: 0096, Loss on trainig: 1.6075, Accuracy: 0.5625
# Batch no: 0097, Loss on trainig: 1.6941, Accuracy: 0.5156
# Batch no: 0098, Loss on trainig: 1.9163, Accuracy: 0.5469
# Batch no: 0099, Loss on trainig: 1.9920, Accuracy: 0.4219
# Batch no: 0100, Loss on trainig: 2.2493, Accuracy: 0.4688
# Batch no: 0101, Loss on trainig: 1.5744, Accuracy: 0.5000
# Batch no: 0102, Loss on trainig: 2.0052, Accuracy: 0.3750
# Epoch: 8/15
# Batch no: 0000, Loss on trainig: 1.7791, Accuracy: 0.5000
# Batch no: 0001, Loss on trainig: 1.9497, Accuracy: 0.5469
# Batch no: 0002, Loss on trainig: 1.8845, Accuracy: 0.5000
# Batch no: 0003, Loss on trainig: 1.8386, Accuracy: 0.5156
# Batch no: 0004, Loss on trainig: 1.8200, Accuracy: 0.5781
# Batch no: 0005, Loss on trainig: 1.9696, Accuracy: 0.3906
# Batch no: 0006, Loss on trainig: 1.7940, Accuracy: 0.5156
# Batch no: 0007, Loss on trainig: 1.9321, Accuracy: 0.5000
# Batch no: 0008, Loss on trainig: 1.9849, Accuracy: 0.4688
# Batch no: 0009, Loss on trainig: 2.1230, Accuracy: 0.4219
# Batch no: 0010, Loss on trainig: 1.6526, Accuracy: 0.5156
# Batch no: 0011, Loss on trainig: 2.1818, Accuracy: 0.4531
# Batch no: 0012, Loss on trainig: 2.1450, Accuracy: 0.4531
# Batch no: 0013, Loss on trainig: 2.0237, Accuracy: 0.4844
# Batch no: 0014, Loss on trainig: 1.7369, Accuracy: 0.5156
# Batch no: 0015, Loss on trainig: 1.6300, Accuracy: 0.5312
# Batch no: 0016, Loss on trainig: 1.9940, Accuracy: 0.4531
# Batch no: 0017, Loss on trainig: 2.0862, Accuracy: 0.4531
# Batch no: 0018, Loss on trainig: 1.4489, Accuracy: 0.5469
# Batch no: 0019, Loss on trainig: 2.3545, Accuracy: 0.3594
# Batch no: 0020, Loss on trainig: 1.9688, Accuracy: 0.4844
# Batch no: 0021, Loss on trainig: 2.0466, Accuracy: 0.4844
# Batch no: 0022, Loss on trainig: 1.9637, Accuracy: 0.4531
# Batch no: 0023, Loss on trainig: 1.9564, Accuracy: 0.5312
# Batch no: 0024, Loss on trainig: 2.4724, Accuracy: 0.3906
# Batch no: 0025, Loss on trainig: 1.6530, Accuracy: 0.5312
# Batch no: 0026, Loss on trainig: 1.8318, Accuracy: 0.4375
# Batch no: 0027, Loss on trainig: 1.7921, Accuracy: 0.4844
# Batch no: 0028, Loss on trainig: 1.9150, Accuracy: 0.4531
# Batch no: 0029, Loss on trainig: 1.9559, Accuracy: 0.4062
# Batch no: 0030, Loss on trainig: 1.7244, Accuracy: 0.5312
# Batch no: 0031, Loss on trainig: 1.7676, Accuracy: 0.4844
# Batch no: 0032, Loss on trainig: 1.7223, Accuracy: 0.4844
# Batch no: 0033, Loss on trainig: 1.3173, Accuracy: 0.6406
# Batch no: 0034, Loss on trainig: 2.0603, Accuracy: 0.4531
# Batch no: 0035, Loss on trainig: 1.6002, Accuracy: 0.5469
# Batch no: 0036, Loss on trainig: 1.4922, Accuracy: 0.6406
# Batch no: 0037, Loss on trainig: 2.0087, Accuracy: 0.5625
# Batch no: 0038, Loss on trainig: 2.1049, Accuracy: 0.4688
# Batch no: 0039, Loss on trainig: 1.5740, Accuracy: 0.5312
# Batch no: 0040, Loss on trainig: 1.9781, Accuracy: 0.5781
# Batch no: 0041, Loss on trainig: 1.8580, Accuracy: 0.5469
# Batch no: 0042, Loss on trainig: 1.8366, Accuracy: 0.5781
# Batch no: 0043, Loss on trainig: 2.1689, Accuracy: 0.4688
# Batch no: 0044, Loss on trainig: 1.7722, Accuracy: 0.5625
# Batch no: 0045, Loss on trainig: 1.7788, Accuracy: 0.4688
# Batch no: 0046, Loss on trainig: 1.8595, Accuracy: 0.5156
# Batch no: 0047, Loss on trainig: 1.6920, Accuracy: 0.5469
# Batch no: 0048, Loss on trainig: 1.9498, Accuracy: 0.5000
# Batch no: 0049, Loss on trainig: 1.6773, Accuracy: 0.5156
# Batch no: 0050, Loss on trainig: 1.9203, Accuracy: 0.5156
# Batch no: 0051, Loss on trainig: 1.9188, Accuracy: 0.5156
# Batch no: 0052, Loss on trainig: 1.5880, Accuracy: 0.5000
# Batch no: 0053, Loss on trainig: 1.3071, Accuracy: 0.6719
# Batch no: 0054, Loss on trainig: 1.6965, Accuracy: 0.5156
# Batch no: 0055, Loss on trainig: 2.3185, Accuracy: 0.4219
# Batch no: 0056, Loss on trainig: 2.0229, Accuracy: 0.5156
# Batch no: 0057, Loss on trainig: 2.6687, Accuracy: 0.2812
# Batch no: 0058, Loss on trainig: 1.6648, Accuracy: 0.5781
# Batch no: 0059, Loss on trainig: 1.6579, Accuracy: 0.5625
# Batch no: 0060, Loss on trainig: 1.7261, Accuracy: 0.6250
# Batch no: 0061, Loss on trainig: 1.8764, Accuracy: 0.5000
# Batch no: 0062, Loss on trainig: 1.9326, Accuracy: 0.5000
# Batch no: 0063, Loss on trainig: 1.9721, Accuracy: 0.5156
# Batch no: 0064, Loss on trainig: 1.6080, Accuracy: 0.5469
# Batch no: 0065, Loss on trainig: 2.1061, Accuracy: 0.3750
# Batch no: 0066, Loss on trainig: 1.6318, Accuracy: 0.5625
# Batch no: 0067, Loss on trainig: 1.8616, Accuracy: 0.3594
# Batch no: 0068, Loss on trainig: 1.8532, Accuracy: 0.5312
# Batch no: 0069, Loss on trainig: 2.0091, Accuracy: 0.4375
# Batch no: 0070, Loss on trainig: 1.3989, Accuracy: 0.5781
# Batch no: 0071, Loss on trainig: 1.8741, Accuracy: 0.5000
# Batch no: 0072, Loss on trainig: 2.0357, Accuracy: 0.5156
# Batch no: 0073, Loss on trainig: 1.8783, Accuracy: 0.5156
# Batch no: 0074, Loss on trainig: 1.9931, Accuracy: 0.4531
# Batch no: 0075, Loss on trainig: 1.7052, Accuracy: 0.5469
# Batch no: 0076, Loss on trainig: 1.6576, Accuracy: 0.5469
# Batch no: 0077, Loss on trainig: 1.9314, Accuracy: 0.4375
# Batch no: 0078, Loss on trainig: 1.9047, Accuracy: 0.5156
# Batch no: 0079, Loss on trainig: 1.7411, Accuracy: 0.4844
# Batch no: 0080, Loss on trainig: 1.8778, Accuracy: 0.4531
# Batch no: 0081, Loss on trainig: 1.6612, Accuracy: 0.5156
# Batch no: 0082, Loss on trainig: 1.7579, Accuracy: 0.5000
# Batch no: 0083, Loss on trainig: 1.7723, Accuracy: 0.4688
# Batch no: 0084, Loss on trainig: 2.0063, Accuracy: 0.4531
# Batch no: 0085, Loss on trainig: 2.1690, Accuracy: 0.4219
# Batch no: 0086, Loss on trainig: 2.0313, Accuracy: 0.4844
# Batch no: 0087, Loss on trainig: 1.5574, Accuracy: 0.5312
# Batch no: 0088, Loss on trainig: 1.8858, Accuracy: 0.5000
# Batch no: 0089, Loss on trainig: 1.8789, Accuracy: 0.5000
# Batch no: 0090, Loss on trainig: 1.5155, Accuracy: 0.5938
# Batch no: 0091, Loss on trainig: 1.8789, Accuracy: 0.4688
# Batch no: 0092, Loss on trainig: 2.2688, Accuracy: 0.4531
# Batch no: 0093, Loss on trainig: 1.8973, Accuracy: 0.5156
# Batch no: 0094, Loss on trainig: 1.9785, Accuracy: 0.5000
# Batch no: 0095, Loss on trainig: 2.0171, Accuracy: 0.4688
# Batch no: 0096, Loss on trainig: 1.9343, Accuracy: 0.4688
# Batch no: 0097, Loss on trainig: 1.9092, Accuracy: 0.4375
# Batch no: 0098, Loss on trainig: 1.4842, Accuracy: 0.5781
# Batch no: 0099, Loss on trainig: 1.6081, Accuracy: 0.5000
# Batch no: 0100, Loss on trainig: 2.0291, Accuracy: 0.4062
# Batch no: 0101, Loss on trainig: 1.8240, Accuracy: 0.5000
# Batch no: 0102, Loss on trainig: 2.2185, Accuracy: 0.5417
# Epoch: 9/15
# Batch no: 0000, Loss on trainig: 1.9362, Accuracy: 0.4688
# ...
# Batch no: 0034, Loss on trainig: 1.3058, Accuracy: 0.6250
# Batch no: 0035, Loss on trainig: 1.3921, Accuracy: 0.5781
# Batch no: 0036, Loss on trainig: 1.9254, Accuracy: 0.4688
# Batch no: 0037, Loss on trainig: 1.4413, Accuracy: 0.6250
# Batch no: 0038, Loss on trainig: 1.6028, Accuracy: 0.5781
# Batch no: 0039, Loss on trainig: 1.7458, Accuracy: 0.4688
# Batch no: 0040, Loss on trainig: 1.6739, Accuracy: 0.5312
# Batch no: 0041, Loss on trainig: 1.9566, Accuracy: 0.5312
# Batch no: 0042, Loss on trainig: 2.0160, Accuracy: 0.4062
# Batch no: 0043, Loss on trainig: 1.8634, Accuracy: 0.4062
# Batch no: 0044, Loss on trainig: 1.1591, Accuracy: 0.6406
# Batch no: 0045, Loss on trainig: 1.5950, Accuracy: 0.5625
# Batch no: 0046, Loss on trainig: 1.7180, Accuracy: 0.5156
# Batch no: 0047, Loss on trainig: 1.8642, Accuracy: 0.4375
# Batch no: 0048, Loss on trainig: 2.1407, Accuracy: 0.4062
# Batch no: 0049, Loss on trainig: 1.6520, Accuracy: 0.5781
# Batch no: 0050, Loss on trainig: 1.5876, Accuracy: 0.5312
# Batch no: 0051, Loss on trainig: 1.2667, Accuracy: 0.6250
# Batch no: 0052, Loss on trainig: 1.4229, Accuracy: 0.6094
# Batch no: 0053, Loss on trainig: 1.4385, Accuracy: 0.6250
# Batch no: 0054, Loss on trainig: 1.5460, Accuracy: 0.6094
# Batch no: 0055, Loss on trainig: 1.4238, Accuracy: 0.6406
# Batch no: 0056, Loss on trainig: 1.5418, Accuracy: 0.6094
# Batch no: 0057, Loss on trainig: 1.6030, Accuracy: 0.6406
# Batch no: 0058, Loss on trainig: 1.4092, Accuracy: 0.6562
# Batch no: 0059, Loss on trainig: 1.4890, Accuracy: 0.5938
# Batch no: 0060, Loss on trainig: 1.7445, Accuracy: 0.4375
# Batch no: 0061, Loss on trainig: 1.4910, Accuracy: 0.6562
# Batch no: 0062, Loss on trainig: 1.6885, Accuracy: 0.5469
# Batch no: 0063, Loss on trainig: 1.6721, Accuracy: 0.5156
# Batch no: 0064, Loss on trainig: 1.4325, Accuracy: 0.5625
# Batch no: 0065, Loss on trainig: 1.9471, Accuracy: 0.4062
# Batch no: 0066, Loss on trainig: 1.9593, Accuracy: 0.5000
# Batch no: 0067, Loss on trainig: 2.0343, Accuracy: 0.4688
# Batch no: 0068, Loss on trainig: 1.4403, Accuracy: 0.5781
# Batch no: 0069, Loss on trainig: 1.4725, Accuracy: 0.6250
# Batch no: 0070, Loss on trainig: 1.7084, Accuracy: 0.5469
# Batch no: 0071, Loss on trainig: 1.7564, Accuracy: 0.5312
# Batch no: 0072, Loss on trainig: 1.4025, Accuracy: 0.6094
# Batch no: 0073, Loss on trainig: 1.7987, Accuracy: 0.4688
# Batch no: 0074, Loss on trainig: 1.4923, Accuracy: 0.5312
# Batch no: 0075, Loss on trainig: 1.5974, Accuracy: 0.5156
# Batch no: 0076, Loss on trainig: 1.9496, Accuracy: 0.4062
# Batch no: 0077, Loss on trainig: 1.8847, Accuracy: 0.4219
# Batch no: 0078, Loss on trainig: 2.2955, Accuracy: 0.3594
# Batch no: 0079, Loss on trainig: 1.4977, Accuracy: 0.5625
# Batch no: 0080, Loss on trainig: 0.9851, Accuracy: 0.6875
# Batch no: 0081, Loss on trainig: 1.4752, Accuracy: 0.6250
# Batch no: 0082, Loss on trainig: 1.4414, Accuracy: 0.6406
# Batch no: 0083, Loss on trainig: 1.6300, Accuracy: 0.5156
# Batch no: 0084, Loss on trainig: 1.6112, Accuracy: 0.5469
# Batch no: 0085, Loss on trainig: 1.5925, Accuracy: 0.6250
# Batch no: 0086, Loss on trainig: 1.4629, Accuracy: 0.5938
# Batch no: 0087, Loss on trainig: 1.5172, Accuracy: 0.6562
# Batch no: 0088, Loss on trainig: 1.6435, Accuracy: 0.5312
# Batch no: 0089, Loss on trainig: 2.0558, Accuracy: 0.4375
# Batch no: 0090, Loss on trainig: 1.6892, Accuracy: 0.4844
# Batch no: 0091, Loss on trainig: 1.2169, Accuracy: 0.6250
# Batch no: 0092, Loss on trainig: 1.7520, Accuracy: 0.4688
# Batch no: 0093, Loss on trainig: 1.7262, Accuracy: 0.5781
# Batch no: 0094, Loss on trainig: 1.5055, Accuracy: 0.5625
# Batch no: 0095, Loss on trainig: 1.8905, Accuracy: 0.5469
# Batch no: 0096, Loss on trainig: 1.5910, Accuracy: 0.5938
# Batch no: 0097, Loss on trainig: 1.7444, Accuracy: 0.5312
# Batch no: 0098, Loss on trainig: 1.8365, Accuracy: 0.5000
# Batch no: 0099, Loss on trainig: 1.9080, Accuracy: 0.4688
# Batch no: 0100, Loss on trainig: 2.3368, Accuracy: 0.3594
# Batch no: 0101, Loss on trainig: 1.6634, Accuracy: 0.5156
# Batch no: 0102, Loss on trainig: 2.1688, Accuracy: 0.3750
# Epoch: 14/15
# Batch no: 0000, Loss on trainig: 1.3651, Accuracy: 0.6406
# Batch no: 0001, Loss on trainig: 1.7212, Accuracy: 0.5156
# Batch no: 0002, Loss on trainig: 1.8287, Accuracy: 0.5000
# Batch no: 0003, Loss on trainig: 1.5285, Accuracy: 0.6250
# Batch no: 0004, Loss on trainig: 1.1957, Accuracy: 0.6250
# Batch no: 0005, Loss on trainig: 1.4098, Accuracy: 0.5938
# Batch no: 0006, Loss on trainig: 1.5557, Accuracy: 0.5625
# Batch no: 0007, Loss on trainig: 1.5784, Accuracy: 0.5469
# Batch no: 0008, Loss on trainig: 1.5842, Accuracy: 0.5781
# Batch no: 0009, Loss on trainig: 1.8361, Accuracy: 0.5000
# Batch no: 0010, Loss on trainig: 1.7596, Accuracy: 0.5469
# Batch no: 0011, Loss on trainig: 1.6895, Accuracy: 0.5625
# Batch no: 0012, Loss on trainig: 1.7860, Accuracy: 0.5625
# Batch no: 0013, Loss on trainig: 1.5272, Accuracy: 0.5625
# Batch no: 0014, Loss on trainig: 1.6013, Accuracy: 0.5312
# Batch no: 0015, Loss on trainig: 1.3767, Accuracy: 0.6250
# Batch no: 0016, Loss on trainig: 1.6692, Accuracy: 0.4844
# Batch no: 0017, Loss on trainig: 1.3656, Accuracy: 0.6250
# Batch no: 0018, Loss on trainig: 1.7713, Accuracy: 0.5156
# Batch no: 0019, Loss on trainig: 1.8715, Accuracy: 0.5156
# Batch no: 0020, Loss on trainig: 1.5936, Accuracy: 0.5625
# Batch no: 0021, Loss on trainig: 2.0222, Accuracy: 0.4531
# Batch no: 0022, Loss on trainig: 1.9094, Accuracy: 0.5000
# Batch no: 0023, Loss on trainig: 1.6287, Accuracy: 0.5938
# Batch no: 0024, Loss on trainig: 1.5641, Accuracy: 0.5938
# Batch no: 0025, Loss on trainig: 1.6414, Accuracy: 0.4688
# Batch no: 0026, Loss on trainig: 1.3205, Accuracy: 0.6406
# Batch no: 0027, Loss on trainig: 1.8271, Accuracy: 0.5312
# Batch no: 0028, Loss on trainig: 1.8992, Accuracy: 0.5000
# Batch no: 0029, Loss on trainig: 1.5885, Accuracy: 0.5781
# Batch no: 0030, Loss on trainig: 1.7164, Accuracy: 0.5625
# Batch no: 0031, Loss on trainig: 1.6478, Accuracy: 0.5469
# Batch no: 0032, Loss on trainig: 1.1570, Accuracy: 0.6250
# Batch no: 0033, Loss on trainig: 1.2977, Accuracy: 0.6562
# Batch no: 0034, Loss on trainig: 1.4356, Accuracy: 0.5469
# Batch no: 0035, Loss on trainig: 1.6447, Accuracy: 0.5781
# Batch no: 0036, Loss on trainig: 1.6333, Accuracy: 0.4844
# Batch no: 0037, Loss on trainig: 1.6793, Accuracy: 0.5000
# Batch no: 0038, Loss on trainig: 1.8956, Accuracy: 0.4844
# Batch no: 0039, Loss on trainig: 1.3861, Accuracy: 0.5469
# Batch no: 0040, Loss on trainig: 1.6796, Accuracy: 0.5938
# Batch no: 0041, Loss on trainig: 1.6898, Accuracy: 0.5781
# Batch no: 0042, Loss on trainig: 1.8209, Accuracy: 0.5625
# Batch no: 0043, Loss on trainig: 1.3856, Accuracy: 0.5625
# Batch no: 0044, Loss on trainig: 1.3870, Accuracy: 0.6094
# Batch no: 0045, Loss on trainig: 1.4709, Accuracy: 0.5469
# Batch no: 0046, Loss on trainig: 1.5324, Accuracy: 0.5938
# Batch no: 0047, Loss on trainig: 1.7974, Accuracy: 0.5781
# Batch no: 0048, Loss on trainig: 1.9282, Accuracy: 0.4844
# Batch no: 0049, Loss on trainig: 1.6916, Accuracy: 0.5781
# Batch no: 0050, Loss on trainig: 1.7387, Accuracy: 0.5781
# Batch no: 0051, Loss on trainig: 1.5823, Accuracy: 0.5781
# Batch no: 0052, Loss on trainig: 1.4780, Accuracy: 0.6406
# Batch no: 0053, Loss on trainig: 1.6377, Accuracy: 0.5156
# Batch no: 0054, Loss on trainig: 1.4647, Accuracy: 0.6250
# Batch no: 0055, Loss on trainig: 2.0134, Accuracy: 0.4531
# Batch no: 0056, Loss on trainig: 1.6288, Accuracy: 0.5625
# Batch no: 0057, Loss on trainig: 1.5627, Accuracy: 0.6094
# Batch no: 0058, Loss on trainig: 1.6705, Accuracy: 0.5312
# Batch no: 0059, Loss on trainig: 1.3268, Accuracy: 0.5938
# Batch no: 0060, Loss on trainig: 1.2645, Accuracy: 0.6094
# Batch no: 0061, Loss on trainig: 1.7726, Accuracy: 0.5156
# Batch no: 0062, Loss on trainig: 1.5452, Accuracy: 0.5625
# Batch no: 0063, Loss on trainig: 2.1425, Accuracy: 0.4688
# Batch no: 0064, Loss on trainig: 1.4809, Accuracy: 0.6562
# Batch no: 0065, Loss on trainig: 1.5107, Accuracy: 0.5781
# Batch no: 0066, Loss on trainig: 1.7873, Accuracy: 0.5469
# Batch no: 0067, Loss on trainig: 1.6975, Accuracy: 0.5781
# Batch no: 0068, Loss on trainig: 1.7511, Accuracy: 0.5312
# Batch no: 0069, Loss on trainig: 1.5658, Accuracy: 0.5938
# Batch no: 0070, Loss on trainig: 1.3929, Accuracy: 0.6250
# Batch no: 0071, Loss on trainig: 1.3548, Accuracy: 0.5781
# Batch no: 0072, Loss on trainig: 1.6689, Accuracy: 0.6094
# Batch no: 0073, Loss on trainig: 1.6847, Accuracy: 0.5625
# Batch no: 0074, Loss on trainig: 1.9301, Accuracy: 0.4531
# Batch no: 0075, Loss on trainig: 1.4081, Accuracy: 0.6562
# Batch no: 0076, Loss on trainig: 1.5854, Accuracy: 0.5938
# Batch no: 0077, Loss on trainig: 2.0210, Accuracy: 0.4844
# Batch no: 0078, Loss on trainig: 1.6123, Accuracy: 0.4531
# Batch no: 0079, Loss on trainig: 1.3444, Accuracy: 0.5781
# Batch no: 0080, Loss on trainig: 2.1154, Accuracy: 0.5156
# Batch no: 0081, Loss on trainig: 1.5743, Accuracy: 0.6094
# Batch no: 0082, Loss on trainig: 1.7423, Accuracy: 0.5938
# Batch no: 0083, Loss on trainig: 1.6822, Accuracy: 0.5469
# Batch no: 0084, Loss on trainig: 2.0251, Accuracy: 0.4531
# Batch no: 0085, Loss on trainig: 1.4573, Accuracy: 0.5781
# Batch no: 0086, Loss on trainig: 1.4620, Accuracy: 0.5781
# Batch no: 0087, Loss on trainig: 1.3939, Accuracy: 0.6250
# Batch no: 0088, Loss on trainig: 1.8989, Accuracy: 0.4844
# Batch no: 0089, Loss on trainig: 1.8588, Accuracy: 0.5156
# Batch no: 0090, Loss on trainig: 1.6035, Accuracy: 0.5781
# Batch no: 0091, Loss on trainig: 1.7814, Accuracy: 0.5000
# Batch no: 0092, Loss on trainig: 1.5539, Accuracy: 0.4844
# Batch no: 0093, Loss on trainig: 1.4953, Accuracy: 0.5938
# Batch no: 0094, Loss on trainig: 1.7897, Accuracy: 0.5625
# Batch no: 0095, Loss on trainig: 1.5243, Accuracy: 0.5625
# Batch no: 0096, Loss on trainig: 1.8677, Accuracy: 0.4688
# Batch no: 0097, Loss on trainig: 1.4857, Accuracy: 0.5469
# Batch no: 0098, Loss on trainig: 1.8225, Accuracy: 0.5312
# Batch no: 0099, Loss on trainig: 1.6565, Accuracy: 0.5625
# Batch no: 0100, Loss on trainig: 1.5229, Accuracy: 0.6406
# Batch no: 0101, Loss on trainig: 1.9880, Accuracy: 0.4688
# Batch no: 0102, Loss on trainig: 0.7076, Accuracy: 0.8750
# Epoch: 15/15
# Batch no: 0000, Loss on trainig: 1.3903, Accuracy: 0.5938
# Batch no: 0001, Loss on trainig: 1.4063, Accuracy: 0.6094
# Batch no: 0002, Loss on trainig: 1.8626, Accuracy: 0.4844
# Batch no: 0003, Loss on trainig: 1.4854, Accuracy: 0.5625
# Batch no: 0004, Loss on trainig: 1.4459, Accuracy: 0.6406
# Batch no: 0005, Loss on trainig: 1.6998, Accuracy: 0.5469
# Batch no: 0006, Loss on trainig: 2.5038, Accuracy: 0.3438
# Batch no: 0007, Loss on trainig: 1.5710, Accuracy: 0.5312
# Batch no: 0008, Loss on trainig: 1.7569, Accuracy: 0.5312
# Batch no: 0009, Loss on trainig: 1.9434, Accuracy: 0.4688
# Batch no: 0010, Loss on trainig: 1.2155, Accuracy: 0.6562
# Batch no: 0011, Loss on trainig: 1.4493, Accuracy: 0.5938
# Batch no: 0012, Loss on trainig: 1.7144, Accuracy: 0.5781
# Batch no: 0013, Loss on trainig: 1.4233, Accuracy: 0.5938
# Batch no: 0014, Loss on trainig: 2.1142, Accuracy: 0.4219
# Batch no: 0015, Loss on trainig: 1.5382, Accuracy: 0.5469
# Batch no: 0016, Loss on trainig: 1.3713, Accuracy: 0.5781
# Batch no: 0017, Loss on trainig: 1.6242, Accuracy: 0.5469
# Batch no: 0018, Loss on trainig: 1.4131, Accuracy: 0.5938
# Batch no: 0019, Loss on trainig: 1.4853, Accuracy: 0.6094
# Batch no: 0020, Loss on trainig: 1.3438, Accuracy: 0.6719
# Batch no: 0021, Loss on trainig: 1.6019, Accuracy: 0.5625
# Batch no: 0022, Loss on trainig: 1.7022, Accuracy: 0.5156
# Batch no: 0023, Loss on trainig: 1.4303, Accuracy: 0.5469
# Batch no: 0024, Loss on trainig: 1.8078, Accuracy: 0.4844
# Batch no: 0025, Loss on trainig: 1.6246, Accuracy: 0.6094
# Batch no: 0026, Loss on trainig: 1.4336, Accuracy: 0.5938
# Batch no: 0027, Loss on trainig: 1.6042, Accuracy: 0.5000
# Batch no: 0028, Loss on trainig: 1.4564, Accuracy: 0.5938
# Batch no: 0029, Loss on trainig: 1.7441, Accuracy: 0.5938
# Batch no: 0030, Loss on trainig: 1.7544, Accuracy: 0.4844
# Batch no: 0031, Loss on trainig: 1.5592, Accuracy: 0.5938
# Batch no: 0032, Loss on trainig: 1.3897, Accuracy: 0.5625
# Batch no: 0033, Loss on trainig: 1.5525, Accuracy: 0.5938
# Batch no: 0034, Loss on trainig: 1.6048, Accuracy: 0.4844
# Batch no: 0035, Loss on trainig: 1.4741, Accuracy: 0.5469
# Batch no: 0036, Loss on trainig: 1.5245, Accuracy: 0.6094
# Batch no: 0037, Loss on trainig: 2.2409, Accuracy: 0.3750
# Batch no: 0038, Loss on trainig: 1.9381, Accuracy: 0.5156
# Batch no: 0039, Loss on trainig: 1.7528, Accuracy: 0.4688
# Batch no: 0040, Loss on trainig: 1.5415, Accuracy: 0.6406
# Batch no: 0041, Loss on trainig: 1.4775, Accuracy: 0.5938
# Batch no: 0042, Loss on trainig: 1.6833, Accuracy: 0.5156
# Batch no: 0043, Loss on trainig: 1.8266, Accuracy: 0.5469
# Batch no: 0044, Loss on trainig: 1.7621, Accuracy: 0.4844
# Batch no: 0045, Loss on trainig: 1.5526, Accuracy: 0.6562
# Batch no: 0046, Loss on trainig: 1.5641, Accuracy: 0.5469
# Batch no: 0047, Loss on trainig: 1.3771, Accuracy: 0.6250
# Batch no: 0048, Loss on trainig: 1.4002, Accuracy: 0.5312
# Batch no: 0049, Loss on trainig: 1.7300, Accuracy: 0.5312
# Batch no: 0050, Loss on trainig: 1.7264, Accuracy: 0.5625
# Batch no: 0051, Loss on trainig: 1.5834, Accuracy: 0.5312
# Batch no: 0052, Loss on trainig: 1.4255, Accuracy: 0.6250
# Batch no: 0053, Loss on trainig: 1.6003, Accuracy: 0.6094
# Batch no: 0054, Loss on trainig: 1.4786, Accuracy: 0.5781
# Batch no: 0055, Loss on trainig: 1.9799, Accuracy: 0.5000
# Batch no: 0056, Loss on trainig: 1.1674, Accuracy: 0.7500
# Batch no: 0057, Loss on trainig: 1.6000, Accuracy: 0.5000
# Batch no: 0058, Loss on trainig: 2.1768, Accuracy: 0.3906
# Batch no: 0059, Loss on trainig: 1.9141, Accuracy: 0.5000
# Batch no: 0060, Loss on trainig: 1.6368, Accuracy: 0.5938
# Batch no: 0061, Loss on trainig: 1.5471, Accuracy: 0.6250
# Batch no: 0062, Loss on trainig: 1.3553, Accuracy: 0.5938
# Batch no: 0063, Loss on trainig: 1.4734, Accuracy: 0.6406
# Batch no: 0064, Loss on trainig: 1.5548, Accuracy: 0.5625
# Batch no: 0065, Loss on trainig: 1.2675, Accuracy: 0.6406
# Batch no: 0066, Loss on trainig: 1.7232, Accuracy: 0.4531
# Batch no: 0067, Loss on trainig: 1.8822, Accuracy: 0.4531
# Batch no: 0068, Loss on trainig: 1.9014, Accuracy: 0.4844
# Batch no: 0069, Loss on trainig: 1.4047, Accuracy: 0.6094
# Batch no: 0070, Loss on trainig: 2.0563, Accuracy: 0.4531
# Batch no: 0071, Loss on trainig: 1.8925, Accuracy: 0.4688
# Batch no: 0072, Loss on trainig: 1.5431, Accuracy: 0.5938
# Batch no: 0073, Loss on trainig: 1.5258, Accuracy: 0.6094
# Batch no: 0074, Loss on trainig: 2.0187, Accuracy: 0.4844
# Batch no: 0075, Loss on trainig: 1.6108, Accuracy: 0.5312
# Batch no: 0076, Loss on trainig: 1.5169, Accuracy: 0.5469
# Batch no: 0077, Loss on trainig: 2.1443, Accuracy: 0.4531
# Batch no: 0078, Loss on trainig: 1.7824, Accuracy: 0.5469
# Batch no: 0079, Loss on trainig: 1.6233, Accuracy: 0.5469
# Batch no: 0080, Loss on trainig: 1.4594, Accuracy: 0.6562
# Batch no: 0081, Loss on trainig: 1.8141, Accuracy: 0.5000
# Batch no: 0082, Loss on trainig: 1.4932, Accuracy: 0.6094
# Batch no: 0083, Loss on trainig: 1.9010, Accuracy: 0.5625
# Batch no: 0084, Loss on trainig: 1.8363, Accuracy: 0.5625
# Batch no: 0085, Loss on trainig: 1.8735, Accuracy: 0.5625
# Batch no: 0086, Loss on trainig: 1.6376, Accuracy: 0.5625
# Batch no: 0087, Loss on trainig: 1.4824, Accuracy: 0.5938
# Batch no: 0088, Loss on trainig: 1.7266, Accuracy: 0.4844
# Batch no: 0089, Loss on trainig: 1.4149, Accuracy: 0.6094
# Batch no: 0090, Loss on trainig: 1.5309, Accuracy: 0.5000
# Batch no: 0091, Loss on trainig: 1.2608, Accuracy: 0.5781
# Batch no: 0092, Loss on trainig: 1.6394, Accuracy: 0.5312
# Batch no: 0093, Loss on trainig: 1.5507, Accuracy: 0.5625
# Batch no: 0094, Loss on trainig: 1.4820, Accuracy: 0.5625
# Batch no: 0095, Loss on trainig: 1.8745, Accuracy: 0.5938
# Batch no: 0096, Loss on trainig: 1.4988, Accuracy: 0.5312
# Batch no: 0097, Loss on trainig: 1.4430, Accuracy: 0.6562
# Batch no: 0098, Loss on trainig: 1.3821, Accuracy: 0.6094
# Batch no: 0099, Loss on trainig: 1.4987, Accuracy: 0.5625
# Batch no: 0100, Loss on trainig: 1.4471, Accuracy: 0.6562
# Batch no: 0101, Loss on trainig: 1.1991, Accuracy: 0.6875
# Batch no: 0102, Loss on trainig: 1.7035, Accuracy: 0.5833

# %%
####VALIDATION#####   
loss_validation = 0.0
acc_validation = 0.0
    
with torch.no_grad():
    #for evaluation
    model.eval()
    for ii, (inputs, labels) in enumerate(dataloaders["valid"]):
        optimizer.zero_grad()
        inputs, labels = inputs.to('cuda'), labels.to('cuda')
        outputs = model.forward(inputs)
        _, predictions = torch.max(outputs.data,1)
        
        loss = criterion(outputs, labels)
        loss_validation += loss.item() * inputs.size(0)
        
        counts = predictions.eq(labels.data.view_as(predictions))
        acc = torch.mean(counts.type(torch.FloatTensor))
        acc_validation += acc.item() * inputs.size(0)
        
        print("Validation batch number: {:04d}, Loss validation: {:.4f}, Accuracy: {:.4f}".format(ii, loss.item(), acc.item()))
# Out:
# Validation batch number: 0000, Loss validation: 0.6395, Accuracy: 0.8125
# Validation batch number: 0001, Loss validation: 0.5817, Accuracy: 0.8750
# Validation batch number: 0002, Loss validation: 0.9313, Accuracy: 0.6875
# Validation batch number: 0003, Loss validation: 0.6638, Accuracy: 0.7812
# Validation batch number: 0004, Loss validation: 0.8265, Accuracy: 0.7031
# Validation batch number: 0005, Loss validation: 1.0045, Accuracy: 0.6875
# Validation batch number: 0006, Loss validation: 0.8459, Accuracy: 0.8125
# Validation batch number: 0007, Loss validation: 0.7196, Accuracy: 0.8438
# Validation batch number: 0008, Loss validation: 0.7599, Accuracy: 0.7812
# Validation batch number: 0009, Loss validation: 0.7229, Accuracy: 0.7969
# Validation batch number: 0010, Loss validation: 0.8847, Accuracy: 0.7812
# Validation batch number: 0011, Loss validation: 0.9106, Accuracy: 0.8750
# Validation batch number: 0012, Loss validation: 0.7280, Accuracy: 0.8000

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
correct_prediction = 0
total = 0
with torch.no_grad():
    model.eval()
    for data in dataloaders["test"]:
        inputs, labels = data
        inputs, labels = inputs.to('cuda'), labels.to('cuda')
        outputs = model.forward(inputs)
        _, predictions = torch.max(outputs.data,1)
        total += labels.size(0)
        correct_prediction += (predictions == labels).sum().item()
        accuracy = 100 * correct_prediction / total
    print('The accuracy of test is: {:.2f}%'.format(accuracy))
# Out:
# The accuracy of test is: 74.48%

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
model.class_to_idx = image_datasets["train"].class_to_idx
model.cpu
torch.save({'structure' :'densenet121',
            'epochs':15,
            'hidden_layer1':120,
            'optimizer_dict': optimizer.state_dict(),
            'state_dict':model.state_dict(),
            'class_to_idx':model.class_to_idx},
            'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model

def load_model(path='checkpoint.pth'):
    #freeze params
    for param in model.parameters():
        param.requires_grad=False
    #checkpoint
    checkpoint = torch.load('checkpoint.pth')
    #model download          
    model = models.vgg16(pretrained=True)
    #load model params
    model.class_to_idx = checkpoint['class_to_idx']
    model.load_state_dict(checkpoint['state_dict'])
    
    return model

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # TODO: Process a PIL image for use in a PyTorch model
    img_pil = Image.open(image)
   
    prepocessing = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    tensor_image = prepocessing(img_pil)
    
    return tensor_image

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %%
image_path="flowers/test/10/image_07104.jpg"
imshow(process_image(image_path))

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # TODO: Implement the code to predict the class from an image file
    preprocess_imag = process_image(image_path)
    
    # Convert from numpy to pytorch tensor
    model.to('cuda:0')
    image_tensor = torch.tensor(preprocess_imag)
    image_tensor = image_tensor.unsqueeze_(0)
    image_tensor = image_tensor.float()
    
    # Run model to make predictions
    
    model.eval()
    with torch.no_grad():
        LogSoftmax_prob = model.forward(image_tensor.cuda())
    predictions = torch.exp(LogSoftmax_prob)
    
    # Identify top predictions and top labels
    top_preds, top_labs = predictions.topk(5)
    
    # Detach all of the details and convert in list to create 
    #dataframe output
    top_preds = top_preds.cpu().detach().numpy().tolist()
    top_labs = top_labs.tolist()
    
    #Create dataframe
    labels = pd.DataFrame({'class':pd.Series(model.class_to_idx),'Type of flower':pd.Series(cat_to_name)})
    labels = labels.set_index('class')
    
    # Limit the dataframe to top labels and add their predictions
    labels = labels.iloc[top_labs[0]]
    labels['predictions'] = top_preds[0]
    
    return labels

# %%
test_image = "flowers/test/10/image_07104.jpg"
predict(test_image, model)
# Out:
#          Type of flower  predictions
# class
# 1         globe thistle     0.802281
# 8         spear thistle     0.114917
# 24            artichoke     0.062766
# 31     alpine sea holly     0.019225
# 94             bee balm     0.000429

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
#path
def check_plot(image_path):
    
    labels = predict(image_path,model)
    
    plt.figure(figsize=(7,10))
    ax = plt.subplot(2,1,1)
    
    img = process_image(image_path)
    imshow(img,ax)
    
    plt.subplot(2,1,2)
    sns.barplot(x=labels['predictions'],y=labels['Type of flower'],color=sns.color_palette()[0])
    plt.show();
check_plot(image_path)

# %% [markdown]
# <font color='red'>**Reminder for Workspace users:** If your network becomes very large when saved as a checkpoint, there might be issues with saving backups in your workspace. You should reduce the size of your hidden layers and train again.
#
# We strongly encourage you to delete these large interim files and directories before navigating to another page or closing the browser tab.</font>

# %%
# TODO remove .pth files or move it to a temporary `~/opt` directory in this Workspace
